# %% [markdown]
# # Overview and Imports

# %% [markdown]
# Recurrent Neural Networks (RNNs) are a type of neural network that are designed to handle sequential data, such as time series or natural language text. They achieve this by using a hidden state that is updated for each time step of the input sequence, allowing the network to maintain a memory of previous inputs.
#
# This notebook contains an implementation of an RNN that can be used for language modeling. The self takes in a sequence of characters and outputs the probability distribution over the next character in the sequence. The network is trained on a corpus of text and then used to generate new text that has a similar distribution of characters as the training corpus.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp

# %% [markdown]
# # Data Prepartion

# %%
class DataGenerator:
    """
    A class for generating input and output examples for a character-level language model.
    """

    def __init__(self, path):
        """
        Initializes a DataGenerator object.

        Args:
            path (str): The path to the text file containing the training data.
        """

        self.path = path

        with open(path, 'r') as f:
            data = f.read().lower()
        
        # Create list of unique characters in the data
        self.chars = list(set(data))

        # Create dictionaries mapping characters to and from their index in the list of unique characters
        self.char_to_idx = {char : index for (index, char) in enumerate(self.chars)}
        self.idx_to_char = {index: char for (index, char) in enumerate(self.chars)}

        # Set the size of the vocabulary (i.e. number of unique characters)
        self.vocab_size = len(self.chars)

        # Read in examples from file and convert to lowercase, removing leading/trailing white space
        with open(path, 'r') as f:
            examples = f.readlines()
        self.examples = [x.lower().strip() for x in examples]
    
    def generate_data(self, index):
        """
        Generates an input/output example for the language model based on the given index.

        Args:
            idx (int): The index of the example to generate.

        Returns:
            A tuple containing the input and output arrays for the example.
        """
        example_chars = self.examples[index]

        # Convert the characters in the example to their corresponding indices in the list of unique characters
        example_char_idx = [self.char_to_idx[char] for char in example_chars]

        # Add newline character as the first character in the input array, and as the last character in the output array
        X= [self.char_to_idx['\n']] + example_char_idx
        Y = example_char_idx + [self.char_to_idx['\n']]

        return np.array(X), np.array(Y)

# %%
data_gen = DataGenerator('../rnn/dinos.txt')
X, y = data_gen.generate_data(2)

# %%
X
# Out:
# array([19,  2, 25, 20,  2,  5,  5,  2, 22, 18,  2,  0,  3,  0, 18])

# %%
y
# Out:
# array([ 2, 25, 20,  2,  5,  5,  2, 22, 18,  2,  0,  3,  0, 18, 19])

# %% [markdown]
# # RNN Implementation

# %% [markdown]
# The RNN used in this notebook is a basic one-layer RNN. It consists of an input layer, a hidden layer, and an output layer. The input layer takes in a one-hot encoded vector representing a character in the input sequence. This vector is multiplied by a weight matrix  W_ax to produce a hidden state vector  a. The hidden state vector is then passed through a non-linear activation function (in this case, the hyperbolic tangent function) and updated for each time step of the input sequence. The updated hidden state is then multiplied by a weight matrix W_ya to produce the output probability distribution over the next character in the sequence.
#
# The RNN is trained using stochastic gradient descent with the cross-entropy loss function. During training, the self takes in a sequence of characters and outputs the probability distribution over the next character. The true next character is then compared to the predicted probability distribution, and the parameters of the network are updated to minimize the cross-entropy loss.

# %% [markdown]
# ## Train
# The train method trains the RNN on a dataset using backpropagation through time. The method takes an instance of DataReader containing the training data as input. The method initializes a hidden state vector a_prev at the beginning of each sequence to zero. It then iterates until the smooth loss is less than a threshold value.
#
# During each iteration, it retrieves a batch of inputs and targets from the data reader. The RNN then performs a forward pass on the input sequence and computes the output probabilities. The backward pass is performed using the targets and output probabilities to calculate the gradients of the parameters of the network. The Adagrad algorithm is used to update the weights of the network.
#
# The method then calculates and updates the loss using the updated weights. The previous hidden state is updated for the next batch. The method prints the progress every 500 iterations by generating a sample of text using the sample method and printing the loss.
#
# The train method can be summarized by the following steps:
#
#
# 1. Initialize  a_prev to zero at the beginning of each sequence.
#
# 2. Retrieve a batch of inputs and targets from the data reader.
#
# 3. Perform a forward pass on the input sequence and compute the output probabilities.
#
# 4. Perform a backward pass using the targets and output probabilities to calculate the gradients of the parameters of the network.
#
# 5. Use the Adagrad algorithm to update the weights of the network.
#
# 6. Calculate and update the loss using the updated weights.
#
# 7. Update the previous hidden state for the next batch.
#
# 8. Print progress every 10000 iterations by generating a sample of text using the sample method and printing the loss.
#
# 9. Repeat steps  2 - 8 until the smooth loss is less than the threshold value.

# %%
class RNN:
    """
    A class used to represent a Recurrent Neural Network (RNN).

    Attributes
    ----------
    hidden_size : int
        The number of hidden units in the RNN.
    vocab_size : int
        The size of the vocabulary used by the RNN.
    sequence_length : int
        The length of the input sequences fed to the RNN.
    learning_rate : float
        The learning rate used during training.
    is_initialized : bool
        Indicates whether the AdamW parameters has been initialized.

    Methods
    -------
    __init__(hidden_size, vocab_size, sequence_length, learning_rate)
        Initializes an instance of the RNN class.
    
    forward(self, X, a_prev)
     Computes the forward pass of the RNN.
     
    softmax(self, x)
       Computes the softmax activation function for a given input array. 
       
    backward(self,x, a, y_preds, targets)    
        Implements the backward pass of the RNN.
        
   loss(self, y_preds, targets)
     Computes the cross-entropy loss for a given sequence of predicted probabilities and true targets. 
     
    adamw(self, beta1=0.9, beta2=0.999, epsilon=1e-8, L2_reg=1e-4)
       Updates the RNN's parameters using the AdamW optimization algorithm.
       
    train(self, generated_names=5)
       Trains the RNN on a dataset using backpropagation through time (BPTT).   
       
   predict(self, start)
        Generates a sequence of characters using the trained self, starting from the given start sequence.
        The generated sequence may contain a maximum of 50 characters or a newline character.

    """

    def __init__(self, hidden_size, data_generator, sequence_length, learning_rate):
        self.hidden_size = hidden_size
        self.data_generator = data_generator
        self.vocab_size = self.data_generator.vocab_size
        self.sequence_length = sequence_length
        self.learning_rate = learning_rate

        self.X = None
        ''' 
        Model parameters:
        W_ax: shape hidden_size * vocab_size
        W_aa: shape hidden_size * hidden_size
        W_ya: shape vocab_size * hidden_size
        ba: shape hidden_size * 1
        by: shape vocab_size * 1
        '''

        self.Wax = np.random.uniform(-np.sqrt(1/self.vocab_size), np.sqrt(1/self.vocab_size), (hidden_size, self.vocab_size))
        self.Waa = np.random.uniform(-np.sqrt(1/hidden_size), -np.sqrt(1/hidden_size), (hidden_size, hidden_size))
        self.Wya = np.random.uniform(-np.sqrt(1/hidden_size), -np.sqrt(1/hidden_size), (self.vocab_size, hidden_size))
        self.ba = np.zeros((hidden_size, 1))
        self.by = np.zeros((self.vocab_size, 1))

        # Initialize gradients
        self.dWax, self.dWaa, self.dWya = np.zeros_like(self.Wax), np.zeros_like(self.Waa), np.zeros_like(self.Wya)

        self.dba, self.dby = np.zeros_like(self.ba), np.zeros_like(self.by)

        # parameter update with AdamW
        self.mWax = np.zeros_like(self.Wax)
        self.vWax = np.zeros_like(self.Wax)
        self.mWaa = np.zeros_like(self.Waa)
        self.vWaa = np.zeros_like(self.Waa)
        self.mWya = np.zeros_like(self.Wya)
        self.vWya = np.zeros_like(self.Wya)
        self.mba = np.zeros_like(self.ba)
        self.vba = np.zeros_like(self.ba)
        self.mby = np.zeros_like(self.by)
        self.vby = np.zeros_like(self.by)
    
    def softmax(self, x):
        '''
        Computes the softmax activation function for a given input array.

        Parameters:
            x (ndarray): Input array.

        Returns:
            ndarray: Array of the same shape as `x`, containing the softmax activation values.
        '''
        x = x - np.max(x)
        p = np.exp(x)
        return p/np.sum(p)
    
    def forward(self, X, a_prev):
        """
        Compute the forward pass of the RNN.

        Parameters:
        X (ndarray): Input data of shape (seq_length, vocab_size)
        a_prev (ndarray): Activation of the previous time step of shape (hidden_size, 1)

        Returns:
        x (dict): Dictionary of input data of shape (seq_length, vocab_size, 1), with keys from 0 to seq_length-1
        a (dict): Dictionary of hidden activations for each time step, with keys from 0 to seq_length-1
        y_pred (dict): Dictionary of output probabilities for each time step, with keys from 0 to seq_length-1
        """

        x, a, y_pred = {}, {}, {}
        # Store the input data in the class variable for later use in the backward pass.
        self.X = X
        # Set the initial activation to the previous activation.
        a[-1] = np.copy(a_prev)
        for t in range(len(self.X)):
            # get the input at the current time step (one-hot vector)
            x[t] = np.zeros((self.vocab_size, 1))
            if self.X[t] != None:
                x[t][self.X[t]] = 1
            # get the input at the current time step
            a[t] = np.tanh(np.dot(self.Wax, x[t]) + np.dot(self.Waa, a[t-1]) + self.ba)

            y_pred[t] = self.softmax(np.dot(self.Wya, a[t]) + self.by)
        
        return x, a, y_pred
    
    def backward(self, x, a, y_pred, targets):
        """
        Implement the backward pass of the RNN.

        Args:
        x -- (dict) of input characters (as one-hot encoding vectors) for each time-step, shape (vocab_size, sequence_length)
        a -- (dict) of hidden state vectors for each time-step, shape (hidden_size, sequence_length)
        y_preds -- (dict) of output probability vectors (after softmax) for each time-step, shape (vocab_size, sequence_length)
        targets -- (list) of integer target characters (indices of characters in the vocabulary) for each time-step, shape (1, sequence_length)

        Returns:
        None

        """

        # Initialize derivative of hidden state for the last time-step
        da_next = np.zeros_like(a[0])

        # Loop through the input sequence backwards
        for t in reversed(range(len(self.X))):
            dy_preds = np.copy(y_pred[t])
            dy_preds[targets[t]] -= 1

            da = np.dot(self.Wya.T, dy_preds) + np.dot(self.Waa.T, da_next)
            dtanh = 1 - np.power(a[t],2)
            da_unactivated = dtanh*da

            self.dba += da_unactivated
            self.Wax += np.dot(da_unactivated, x[t].T)
            self.dWaa += np.dot(da_unactivated, a[t-1].T)

            da_next = da_unactivated

            self.dWya += np.dot(dy_preds, a[t].T)

            # clip gradients to avoid exploding gradients
            for grad in [self.dWax, self.dWaa, self.dWya, self.dba, self.dby]:
                np.clip(grad, -1, 1, out=grad)
    
    def loss(self, y_preds, targets):
        """
        Computes the cross-entropy loss for a given sequence of predicted probabilities and true targets.

        Parameters:
            y_preds (ndarray): Array of shape (sequence_length, vocab_size) containing the predicted probabilities for each time step.
            targets (ndarray): Array of shape (sequence_length, 1) containing the true targets for each time step.

        Returns:
            float: Cross-entropy loss.
        """

        return sum(-np.log(y_preds[t][targets[t], 0]) for t in range(len(self.X)))
    
    def adamW(self, beta1=0.9, beta2=0.999, epsilon=1e-8, L2_reg=1e-4):
        """
        Updates the RNN's parameters using the AdamW optimization algorithm.
        """
        # AdamW update for Wax
        self.mWax = beta1 * self.mWax + (1 - beta1) * self.dWax
        self.vWax = beta2 * self.vWax + (1 - beta2) * np.square(self.dWax)
        m_hat = self.mWax / (1 - beta1)
        v_hat = self.vWax / (1 - beta2)
        self.Wax -= self.learning_rate * (m_hat / (np.sqrt(v_hat) + epsilon) + L2_reg * self.Wax)

        # AdamW update for Waa
        self.mWaa = beta1 * self.mWaa + (1 - beta1) * self.dWaa
        self.vWaa = beta2 * self.vWaa + (1 - beta2) * np.square(self.dWaa)
        m_hat = self.mWaa / (1 - beta1)
        v_hat = self.vWaa / (1 - beta2)
        self.Waa -= self.learning_rate * (m_hat / (np.sqrt(v_hat) + epsilon) + L2_reg * self.Waa)

        # AdamW update for Wya
        self.mWya = beta1 * self.mWya + (1 - beta1) * self.dWya
        self.vWya = beta2 * self.vWya + (1 - beta2) * np.square(self.dWya)
        m_hat = self.mWya / (1 - beta1)
        v_hat = self.vWya / (1 - beta2)
        self.Wya -= self.learning_rate * (m_hat / (np.sqrt(v_hat) + epsilon) + L2_reg * self.Wya)

        # AdamW update for ba
        self.mba = beta1 * self.mba + (1 - beta1) * self.dba
        self.vba = beta2 * self.vba + (1 - beta2) * np.square(self.dba)
        m_hat = self.mba / (1 - beta1)
        v_hat = self.vba / (1 - beta2)
        self.ba -= self.learning_rate * (m_hat / (np.sqrt(v_hat) + epsilon) + L2_reg * self.ba)

        # AdamW update for by
        self.mby = beta1 * self.mby + (1 - beta1) * self.dby
        self.vby = beta2 * self.vby + (1 - beta2) * np.square(self.dby)

    def sample(self):
        """
        Sample a sequence of characters from the RNN.

        Args:
            None

        Returns:
            list: A list of integers representing the generated sequence.
        """

        # initialize input and hidden state
        x = np.zeros((self.vocab_size, 1))
        a_prev = np.zeros((self.hidden_size, 1)) 

        # create an empty list to store the generated character indices
        indices = []

        # idx is a flag to detect a newline character, initialize it to -1
        idx = -1

        # generate sequence of characters
        counter = 0
        max_chars = 50 # maximum number of characters to generate
        newline_character = self.data_generator.char_to_idx['\n'] # the newline character

        while (idx != newline_character and counter != max_chars):
            # compute the hidden state
            a = np.tanh(np.dot(self.Wax, x) + np.dot(self.Waa, a_prev) + self.ba)

            # compute the output probabilities
            y = self.softmax(np.dot(self.Wya, a) + self.by)

            # sample the next character from the output probabilities
            idx = np.random.choice(list(range(self.vocab_size)), p=y.ravel())

            # set the input for the next time step
            x = np.zeros((self.vocab_size, 1))
            x[idx] = 1

            # store the sampled character index in the list
            indices.append(idx)

            # update the previous hidden state
            a_prev = a

            # increment the counter
            counter += 1

        # return the list of sampled character indices
        return indices 
    def train(self, generated_names=5):
        """
        Train the RNN on a dataset using backpropagation through time (BPTT).

        Args:
        - generated_names: an integer indicating how many example names to generate during training.

        Returns:
        - None
        """

        iter_num = 0
        threshold = 5 # stopping criterion for training
        smooth_loss = -np.log(1.0 / self.data_generator.vocab_size) * self.sequence_length  # initialize loss

        while (smooth_loss > threshold):
            a_prev = np.zeros((self.hidden_size, 1))
            idx = iter_num % self.vocab_size
            # get a batch of inputs and targets
            inputs, targets = self.data_generator.generate_data(idx)

            # forward pass
            x, a, y_pred  = self.forward(inputs, a_prev)

            # backward pass
            self.backward(x, a, y_pred, targets)

            # calculate and update loss
            loss = self.loss(y_pred, targets)
            self.adamW()
            smooth_loss = smooth_loss * 0.999 + loss * 0.001

            # update previous hidden state for the next batch
            a_prev = a[len(self.X) - 1]
            # print progress every 500 iterations
            if iter_num % 500 == 0:
                print("\n\niter :%d, loss:%f\n" % (iter_num, smooth_loss))
                for i in range(generated_names):
                    sample_idx = self.sample()
                    txt = ''.join(self.data_generator.idx_to_char[idx] for idx in sample_idx)
                    txt = txt.title()  # capitalize first character 
                    print ('%s' % (txt, ), end='')
            iter_num += 1

    def predict(self, start):
        """
        Generate a sequence of characters using the trained self, starting from the given start sequence.
        The generated sequence may contain a maximum of 50 characters or a newline character.

        Args:
        - start: a string containing the start sequence

        Returns:
        - txt: a string containing the generated sequence
        """

        # Initialize input vector and previous hidden state
        x = np.zeros((self.vocab_size, 1))
        a_prev = np.zeros((self.hidden_size, 1))

        # Convert start sequence to indices
        chars = [ch for ch in start]
        idxes = []
        for i in range(len(chars)):
            idx = self.data_generator.char_to_idx[chars[i]]
            x[idx] = 1
            idxes.append(idx)

        # Generate sequence
        max_chars = 50  # maximum number of characters to generate
        newline_character = self.data_generator.char_to_idx['\n']  # the newline character
        counter = 0
        while (idx != newline_character and counter != max_chars):
            # Compute next hidden state and predicted character
            a = np.tanh(np.dot(self.Wax, x) + np.dot(self.Waa, a_prev) + self.ba)
            y_pred = self.softmax(np.dot(self.Wya, a) + self.by)
            idx = np.random.choice(range(self.vocab_size), p=y_pred.ravel())

            # Update input vector, previous hidden state, and indices
            x = np.zeros((self.vocab_size, 1))
            x[idx] = 1
            a_prev = a
            idxes.append(idx)
            counter += 1

        # Convert indices to characters and concatenate into a string
        txt = ''.join(self.data_generator.idx_to_char[i] for i in idxes)

        # Remove newline character if it exists at the end of the generated sequence
        if txt[-1] == '\n':
            txt = txt[:-1]

        return txt

# %%
data_generator = DataGenerator('/home/tiendat/AI-LAB/NLP/pytorch/rnn/dinos.txt')
rnn = RNN(hidden_size=200,data_generator=data_generator, sequence_length=25, learning_rate=1e-3)
rnn.train()
# Out:
# iter :0, loss:82.359667
#
# Uwphcdiyxvpknw
# Spjuoxjozvswhvilkqkgbeje
# Lrds
# Fimgvratoulfmhpjlfmcyqnheromznaxtujtiblsbkvtyvvwr
# Ujkcqeazfdojavkfuszptwxoobhwezerpembsdrnrzvqywdbdv
#
# iter :500, loss:67.332526
#
# Eabymautuasavjdvoamacohjdpiwnruzjai
# Yrlcgqoruogqtdqwlzocnjmzhqhmuafwfkmjbr
# Nzcazxukmodahacrzxvamr
# Drgcvppqrahqi
# Mmcabowcxjujykmshabadxxaxahzgpxavamjbaqrnasrnkix
#
#
# iter :1000, loss:57.525419
#
# Ihnvxaifnauautioph
# MguacejrqlgsgzsrzefaqyxhyafqmzvqmfnajhifbqdqlfwaedG
# Timop
# Mv
#
#
# iter :1500, loss:51.502278
#
# CqveuwygjmpaftnhskishakacpipuobpeacfuqwabamamynwikUvsqya
# IasrgpierrwtbwprtwlaxmuaujmrwacwbacrboljlkgucjecgaQamrmanzcrultavbytoyjkbaufrqdnmpbrvcbofkyamjvwsveaZanzesia
#
#
# iter :2000, loss:47.837806
#
# Zswyiycquvlauj
# ZdcxiesakackzgzcqfhaxncrqhbnktqschtafcsadxqphgntuoXpkxkgwwsyulmwjxwrixkpiguxfxnqcnfwq
# RavayaqazddgsasadpbbirfacxeaiauxzdwooxbdtrnpxovojaTodafcjlzgmgkakgqfctbrkjmohfcgnavstawgywcojofaqrha
#
# iter :2500, loss:45.584445
#
# RnbymwmasacohqbtbbkdxrdhnqzctrxgechbeclyzfbazlljtaXxwdhkeabvbmnmcedalajftanavhfwgclacrtmivpacr
# Uattquwacrgqgrdtx
# Owuvupfgllhahylgl
# Udcazfkfyabauh
#
#
# iter :3000, loss:44.170008
#
# Xrmjdpuzigvnwberkkvpxnukjfcazaghl
# Wfdabscqu
# C
# Uaxaga
# Knijaxccusshzhvocjdsxesapllxnusmsjbakomqef
#
#
# iter :3500, loss:42.882261
#
# Mhnbfvlnsknafzmxiedtojchsyuyncvjfjbpvbljhruqxei
# VemdumitqrxipokeeazyuwiklcdgfaijctgtiadagzfevrnhurFpfdjkcqltgyucistwcpjwkkdgcwmslkxrfqyjygrfxztzezvkVlxadahwi
# Sqowlqcnyocaqmlkyamygmhkiqcrzriosmfaiwmrgaeadexk
#
#
# iter :4000, loss:40.308656
#
# Kjyufgjqdxixgwjzhkgbfqgwjjdjydcqg
# YjhvmrganxfxjqwjgqfxyamjdqjggwvjgzkwjzlvmqyqmvpkvyGziaxads
# Fpskkxzcmkkwgxqqimdjwkvwxwdvgjgkbkykszwkkzzzdjqz
# Uwysnjzkvzwjnqqjzkdwzkmzfjqjbtpylbgkvwwgkwnqfvirgp
#
# iter :4500, loss:42.859471
#
# Yv
# Fmdidryank
# NdbryrnrhrllcinduaordappnmqaqnpgfpefjfwvpojkjrhrhoNrxsfpufwmwqguykw
# Trbemaqafcwr
#
#
# iter :5000, loss:43.075203
#
# Wydijtqkxvu
# Lvltcectguo
# Xathqdmdgtbrxvyno
# Duwduzpnlolccxfhxwqbuoxguafnxfgstsga
# Pof
#
#
# iter :5500, loss:42.882546
#
# Aiixrdwjnsyxqbqvdncuwwxlrtesnp
# Nbsjxbrwwyustmdlrscpdmrglxzxqbvgdvqvubelg
# Aubiahepvtcweni
# Rnekolminiwsrnbxd
# Qdw
#
#
# iter :6000, loss:41.244063
#
# MnkpfnigsdzyhvayrbpoagrqjihitefxfvrsgulqlaqvooiuadGbveofg
# Fctyosusxizcfuouzarvpsfurgbumbx
# MokazyrfalmpjsqmeswmzpwcdlryqekqqvocwaukwqolkmzixhYabsbkfbrvclmqgsknoc
#
#
# iter :6500, loss:39.942819
#
# Gi
# HhagjxksfugnxvetojeuvccetvzvagcwekhuoasrovdkzgtilwKurmcgrxtvcnroaychewapyejgrrpsgehbmnlyynyxjvsudbdpAvebttdhcvmoo
# Pqjgfvysxjouldqgfcsvkgs
#
#
# iter :7000, loss:39.112633
#
# Ulkhfdbszpxkhucsuewvyh
# Mxqfcbtvranxhzozagalahpmpwnnsgyjfui
# Swrtcqfmofjbxbiuvqnmkudmhprkla
# Gzz
# Fiyjjzaildxzrmahtlp
#
#
# iter :7500, loss:38.550222
#
# Qnsoohbxnrrifdtxpuzvdaaaldu
# Kiemxzvtjkcptglhozszaseuyxtvssoqnodbvg
# JiatmhlnfsqfdxkzxnwuefqwkbgfpwodedscazcgrkcohhonjsNzrvriafstvxvxpczxnuilzyhtago
# Glljrwrribrjcp
#
#
# iter :8000, loss:38.107859
#
# Nschdajagvzzvrgenjqcirshtcnrjfqfmozy
# Jxcpuknclawe
# Bkaqzakslmpw
# Qkzrsg
# Iwophiftetpfdrspbezrcgyxwapoijsejrhotmdnih
#
#
# iter :8500, loss:37.774623
#
# Yngpik
# Vncilszjfjhrzqxzepemvtudmtjlz
# Ogcoxbgts
# ScfvnajokiuettktufsbmvsrxgxpkaqvishlsynlsjpvbunpzeIzqmmpbnouvefnjpkckmzgnwesygbmgufjruotmzajpqo
#
#
# iter :9000, loss:39.038202
#
# MztrylcjwopivjmdenquqavdmbpcnalztbersjvbrswjcjlkpwG
# Zjiho
# Yxluhlq
# Beqridi
#
#
# iter :9500, loss:39.071555
#
# Denrfkuqnoyodvrrtakfeemoxnmb
# Kaja
# XebyorsacrhfcrlyuruatqnaxyzdbkkfujyyyhyvzkmpsfudcrLivhhohryphlssspepbtujloeeupddulxabtfsqxukorwoua
# Dnvakllupqwehlymirjdqffcuvdya
#
#
# iter :10000, loss:38.519368
#
# Hruym
#
# Ftamteqe
# Loqn
# Simpfbdcuytffpuqhekrditblcrrselvvtlfkkmccokilaermy
#
# iter :10500, loss:37.951220
#
# Lh
# Brlsncinbed
# RrvsrvlycvtpnocbnrhagvphbcznpokvlrxyuysgirbkqpqvkaRaieprydisgtjrxobrpxxmziuezwlhwpjmtvuofnjhcpmcgpugMrgwarhbsrgagjuxkmgjmtseqrkwkaiakahlthbtvmimuhoyu
#
#
# iter :11000, loss:37.544666
#
# Irneperaoriryc
# Crnburhhltvducnctjguhodterwopplenwpqczhx
# ItididgqbzynlzhkvqvvfkwbsxgzczywnzfqskcgizymicxbzkTej
# Mrdkecb
#
#
# iter :11500, loss:37.265772
#
# EaapkylprtijgkgawiisiavujwmryapwiacfjounqeohqazadrHpnputrczeloiwttqs
# Rpsgkoapxhspitureciywjopcdzegyuxofleucma
# Eonexxmrjafhlfpzmelec
# Lttospurllkxsnipuwifkbjwitxctaetzqouloypq
#
#
# iter :12000, loss:36.874943
#
# Daap
# Eelayapenqtnaacxckh
# Lpxfrreblefoqrs
# DptcukafsfnunadamtiqthtrcslymouxwabklgiwdwujhdbhuzRlua
#
#
# iter :12500, loss:36.463800
#
# Dkoasltjlf
#
# BgicahicuaubnoovmoloefldeadphogejavsvalvicolpjohoqLoobaatthrnpnhdtsxuruosbrhfax
# Olrgrxqf
#
#
# iter :13000, loss:36.261398
#
# Uaymigwcpoutaqnals
# Trnrofjizoaeoopanxbg
# Dgoicaycttnmodlhghudqogaieqcmohxnl
# Ehicdotgwlnotmektmnizroeucwtiodckabobreroonxb
# Oszldatddooxmwulsowtqpjxzrjrmsjmrxbwqcjcbfjkmqgrpv
#
# iter :13500, loss:35.713551
#
# Y
# Gjlcbzlnsfiyxyiempilfolwyp
# Docwteixfhvwbaxqhoxptcbiijmr
# Ljt
# Eaxymrlgmectoqunxlhordadtqytmeoosoyau
#
#
# iter :14000, loss:36.201230
#
# Ilkozvxgypzpwghz
# Xahifo
# Ohftselaidcxcru
# Dbvputdhumpdlp
# Ehyedefakeq
#
#
# iter :14500, loss:36.317595
#
# Lshoskdkxbgcdoypmqmkxjzvgi
# Yomweqg
# OcxjxzdcvpikrvyuzlhxedmqgkgzvqgrlokwjkqucxiwzosegoLzxnqkyqbkzcbb
# E
#
#
# iter :15000, loss:36.416394
#
# Vrqkhr
# Rozdxhmecrwoarzhgowiy
# X
# NwjoqpydwdvgqoranxnfhaovdlhnlimhuitfoxnvcskgiutombXcwoexnelczbsqbomagywvvyjutmmwurzavfnaoajszjrbwcsg
#
# iter :15500, loss:36.555601
#
# OukfaedvkqfkjjuvliwmwvnmsreeaunedvxfxcsfhbigvopqwsLhuatarinfmoroqjszegzoehlwyavjnkuaqahjdskedd
# Lz
# YvgrlgcahaomcjuglgmbpgaydtiviitzvkoapnvhbaibuejjbsIbucfxpkmgddfexgsbjbhxbekwzihkdj
#
#
# iter :16000, loss:36.575085
#
# Dzqjiixwg
# Ojjr
# LqpevjtkxqaobqxflpgnlztwsmhkomgwkvjjsduzpzsnxjpwsuRmxgukmjihmoxecrdcsrmkbjabozmii
# Oxcysveqqiydphqznzeeffgmrrtpxi
#
#
# iter :16500, loss:36.303276
#
# Oxibjygrycyengdiqouuqwewafzmravxuu
# Rpkjzvsyhfarfjjjxumrqokhtq
# Islaupggxuarmcuhsobizmkgpd
# Hvqc
# Xpismoqdjomspjpekypvqopaurtxuaoxwohtmrusmohgxasxq
#
#
# iter :17000, loss:36.072513
#
# Iqrvlcsnfroaekxtcaubpompcu
# Rbxr
# Opvkvaujlsxfoayrgnfec
# IhmhhouamackzmgiurbouatmarefmdieibegnuyoxwnkuzutmsOpxb
#
#
# iter :17500, loss:35.972990
#
# Rhfrbwti
# Okm
# Oqxgbk
# LvqamowuzvwarmjejeboyfqkpimaktnopbmhihmzzghmmiyrlgLxhiz
#
#
# iter :18000, loss:35.632529
#
# Iyighakxcoxylrztktqqn
# Omws
# Iwbxfwgipurgfnwat
# Oqkgz
# Enkgxhcxufxffqmbbqkfzijnmdtdjemdwgcfzgqddlfhqmkppg
#
# iter :18500, loss:35.567771
#
# Owixvcuodjxj
# Dmz
# Hgxkv
# P
# Ohqbcwftj
#
#
# iter :19000, loss:35.516009
#
# Onmgmjsbrztxqqdlobiaio
# UkvfmmawlxdofyqffykkbnuqdyuqtqzrhufgbcssctekseaqirOpwjypmltwnudkigeusjcgfgxckobrkwjhzusggewzvs
# Ogsf
# Ommtivhqubzc
#
#
# iter :19500, loss:35.199769
#
# Onxrydrpsaboprt
# Oyxrzfzkmmwykimljpzcmrcfztafhdw
# Otuzhgmwnodiwhidvtyofdzojnkuxxjoufebekwrbrgfhgs
# Lxmfavwobozohcwaubhcugpbnbvs
# L
#
#
# iter :20000, loss:34.989525
#
# OxnfndrrzfbumwitjxgvkwjrqyqhzgkfqetbfckdyxxgfgwmxfOpkgwigzilqewmdykhkpkzwsgpdzxampbjudkimykfuhzjvpihOgzbjpkphwkgjggqkfwqzpkxmomnmrhvjdgtqoxrkfvnphmimmYkiffmjfxcpeiwhskyjawvpfyg
# Okfvqokmfgzfiqzgkbhxjpkxkpw
#
#
# iter :20500, loss:35.247744
#
# Otmqkrlskwz
# Opxj
# Opbgpwgemacoxmhfgruzuy
# Ntmwmhcd
# Ovmjzafqxezwdhjkyxgedqakdjekgyupupsebvejxswh
#
#
# iter :21000, loss:35.257151
#
# Omijdvu
# Dvkqmlfdwdeyuoemcydhjvj
# Ogkpjusmux
# Lsvgkmk
# Dlmchrfcuawcbplpqatmurmu
#
#
# iter :21500, loss:35.238829
#
# Oifqwugx
# Ozqvxjm
# Avkhqkbffcbjmpmrdkqadey
# Oznzjhzpcb
# Opxmic
#
#
# iter :22000, loss:35.046039
#
# Ekkfpwebpwrzyrmuskhf
# Ijwafmxjgm
# Omib
# Tmijb
# Ttn
#
#
# iter :22500, loss:34.749534
#
# Ixnzwb
# T
# Ojmwew
# Oulqmutfwjc
# Lkmzfz
#
#
# iter :23000, loss:35.000745
#
# Okzwuwbppjycpxvp
# Tqfndqu
# Lxvukfypdd
#
# Lkdb
#
#
# iter :23500, loss:35.047001
#
# Omfvurpyuspwpv
# Emqwlv
# Okuvfoab
# Lgmacxx
# Lwfwj
#
#
# iter :24000, loss:34.782182
#
# Ohbj
# Ecu
# Llbrmaqfxajpufpfqp
# Opivurkimomuaef
# Omf
#
#
# iter :24500, loss:34.530825
#
# Lkx
# Ltbqs
# O
# O
# Okrxo
#
#
# iter :25000, loss:35.591844
#
# Tim
# Lkvu
# Lobhfrukhtidlksqkofachjtjgltevvotazexidrcy
# L
# Oglpzcupwazyvhxdxnprqaqvtzlnympavsz
#
#
# iter :25500, loss:37.224036
#
# Ov
# Lqntaakwksznwofjjkzon
# OpzlzvmvmctomokmmjzomthfbusihvanzpeglrlpurwccptabfOtv
# Ovkvcdxo
#
#
# iter :26000, loss:37.799029
#
# OtfzikawttyzkziaeodouylncjetsqqdwvvriljjvecpbhugnyOxwofnnezmauhb
# Cintigehutq
# Eoxgweadzpjxigwgisihfax
# Olvgvlgbaomgzxcwdctaindaztfirojeuhipcalawgschvyv
#
#
# iter :26500, loss:37.867630
#
# DxkpzskjogucktchjvehjxxznalrsrpahczciqmeulzalvtlerOgfrfssfmpmpvwnehxvuxxfnxgntlnkreammywdaw
# Ovz
# Ltm
#
#
#
# iter :27000, loss:37.811315
#
# Ovmhgcmglb
# Oivjudxiltuflkvgwsnezpi
# Olzkhrluddopcpmrr
# Tmqmumzjqmajsrsyl
# Oomfirsklerokwsastuzboz
#
#
# iter :27500, loss:37.629359
#
# Ol
# OlnaycloislkhcuqjtufsfycaankixuchallmkuacjhynexqzsTnikbmpucrjyejoqiqnvjqfbcdtesoptcjpjsknrhvhf
# OmngtgnjvetfbaywmknfsonwvfygkhdkddxknougixvluuwogwKk
#
#
# iter :28000, loss:37.474140
#
# Nzmylqpgmr
# Ei
# Omkqmz
# Ox
# Otxgofjywpnjzpwo
#
#
# iter :28500, loss:37.346010
#
# Onlagjfld
# Ohmsedlotlqaijl
# IvkabaqotwhwbkldoouqinlrsespfgiagkfmvamalmxjllwjomDwzwyzxacqybkhnremxago
# Tpmymardfwgnsrnpfoceuvxghilkixuguwvklrvyzaesdeeaxa
#
# iter :29000, loss:37.380355
#
# Otmjsvspjwpfvxigzabzzlfxzgstzlwakfqlxthfedyc
# Ohqxsdiovo
# OqwnygnhjnlpwhpenhkaicmlkgatujbymmzanukpqcdoitbgjjNnngmooscmprftqzuokpilqokf
# Dxxwaktr
#
#
# iter :29500, loss:37.770903
#
# Lgwuopbrurigfnznwwnauaeojbnciakosrv
# Olzophuuzolrepllwdkzhrhtlhpfudusqecvosmn
# Ekszwktotpggtnttqakfdbjssehgoregwojxjldee
# Oijshrmapfualxfdcuwfkfhncfxr
# Lp
#
#
# iter :30000, loss:38.035226
#
# Oymgvsifxzkbow
# Lvqgwlwouoivwrzxstwelriapckh
# Oslbjmuduaddmtxmgjqmiglywpuwimvni
# Ojqmzvigajvon
# Oqxekavpxamgwjcbwcuswtdmmgfuuovpzbqtpnzbvauhjajqqn
#
# iter :30500, loss:38.131759
#
# RowushupivmfcoebirqzmusbnrhihtuobtqlfyxxginjcriezyLhtrsrqffryok
# Ominkvuv
# LhsofqkrmnkderwgosqyuyuvpmkefesskchdwtphuauizszmhvLgvxnrvesuureawf
#
#
# iter :31000, loss:38.315696
#
# OvlzhqmspalrshnnqksiaoifuzlmhruezvpbmtjdvvnoqyhdocIrnaj
# Escofekazgqiqz
# Ivkyb
# Poualtcassyryyzmsplbjjuhmawoqrqxuh
#
#
# iter :31500, loss:38.289743
#
# LuqjnbffmybxjhpoqafebsioycziyoawsoibstwmhrhnkjyfqoLswhnvkprajjcfni
# LvweyckrhrzockqtgkxxgrpxazghffjlqtmrkjbnpeyhvnieefRplnqqxxmxwesrqwgkebkumdscwxzylhckgenrujarryjrcfwdLvajmrbvmmkgezxozogfbqwkyrnexruovrmriagnvelzctbczr
#
# iter :32000, loss:38.516288
#
# Ljzalobdilyomaxp
# OqzwkoiddwnpsklgiezxqbytmodytxlfdfvjiamfjbhrfgdwrySvupmodaiiveklsrzktqlqqddptaimkgsvd
# OgvgsfuteqzaximphvxalscplpcbfudqnantptpymhcaesxhcfLxlqvpckedxrmgaynqoluimp
#
#
# iter :32500, loss:38.720304
#
# Iji
# Otlxccbfewisxjdeggpxbjvzhzgbteeovc
# Dtmazbxruoyz
# Elzektvzbtld
# Eqoenf
#
#
# iter :33000, loss:38.691371
#
# Ovllnjdkonx
# Lnncfvxangfjurszctdclkgphizrow
# LjnvqewoclfjtrbxcrmwvmetssdxjqdplwlzmcmwsedoyefnjeLimaumytidlymhrxbwigsylqwketiainfzmuerdkmrbgwibaaqLmgtmydoumvzncehutbjmqdhuslggpmzghgbbwejkrlrxrtwfh
#
# iter :33500, loss:38.375863
#
# Lslkncbcfnwt
# Osncmuvxmpuofviolhzrkwnc
# Ipn
# LqqwdrvjahljiknnaovtiemxitmazmlhwwhipkufhgiqcylhvqEjuoithljytjjh
#
#
# iter :34000, loss:38.003524
#
# Lxmhzepzagwfkbkryuzgzomeaznovohwuykfbprohdltuvezd
# OzfflmnndapwqvkvmqvymandwjpfhkvnqpipqamewaltxavogcLg
# Nneipbxqukxtkrzqwtdfyqehjuuyvqhthrgz
# Pgjj
#
#
# iter :34500, loss:37.590417
#
# Lvfihgetxqnbpnsgjpkmqszrkawduha
# Ovqameuxcbiwqbimklkvusnrqyayuhadjxit
# Lshfbafdimvawfuxkrjradwicivgkrwzpmhauzyztavopxjf
# Eiujqsksjxydpejicgw
# Lttqerwqpnqqqawxwatsfcdehjgfnrjsqginwvusioieuryowc
#
# iter :35000, loss:37.276172
#
# Btqanwqpkhqqrglxfslohkuohwogfcnmyv
# Lxqvqlmeetqwfo
# Hwph
# LqmejapwmbastyltscdcnzarwkncwrlvvgcxhjmamhhcykbtyjLdkeygagvofouuywwwyrbemxajmcllzxwkjqqlaxokjwdgzlex
#
# iter :35500, loss:37.638481
#
# Onoyxpovoeanrbagxer
# Dtrgabfcwqrur
# Rwodpugsekeaakbpu
# Dqlnrztmnxh
# Rzazyqgrbbgnmadsxafsxnapwwpdrnzdcmnrfndcdkohrkkkaq
#
# iter :36000, loss:37.176803
#
# ExusvsayirrqgicxkmcodxcqzxvwipjndwebaeoyvlfvebplkvDjunaqkuauzcooesijb
# Y
# O
# Infgabwulljkwbqkouejqtusejfzluimalruawtba
#
#
# iter :36500, loss:37.108141
#
# DokzfsfcywmckoxqdzcucjmvbkpiolcjwwqvdqtwjziusudhapDplmcmemolvpjyricvqlo
# Rtkgaupsjloppbnux
# Eziywmyktrxipbodosfqguovlvaywhqtkhc
# Ywmuioaupbitfiyw
#
#
# iter :37000, loss:36.597612
#
# Dslqqyzziqritbbhpjclp
# RwnsvqyrpytuoagsoxlnqfmwejgignrqpaosjufczhmmxqruymDmujiwfzoktue
# Yhvxihgmtmkhmuosozpjfpxvrchksslnltcyhxbem
# Ellgkpfsecfjokpftmsbczdxrrhmoxxayern
#
#
# iter :37500, loss:35.701993
#
# Ohelfxptxuvioevtvbiul
# Ixetdik
# Lnzgnttuaq
# Lnv
# Dhtftxnrbwlovqqsoqbqmd
#
#
# iter :38000, loss:37.449253
#
# Dupdkhdhvqtlmfozpdfmgbyzcizqapzzfuqfylmxjwruokv
# Rnvxvtteebonvvahgxgxygw
# Lxte
# Otvttopubhyuuslc
# Rsljsezqnfasw
#
#
# iter :38500, loss:37.894530
#
# Dueuj
#
# Dmeow
# Usahvwrcskk
# Pcvbulaewmyqjdzfvyrgunrgyphnzmkmpax
#
#
# iter :39000, loss:38.147298
#
# Rgweqjeey
# Uuqioifndmvm
# Iwrzqurmrvdmxuvyejqskhzeymcbagkkpcwtejquwfd
# Lfrn
# R
#
#
# iter :39500, loss:37.978098
#
# OgafzcotptascfwdichiterdaffuutmpwsjtzgkyhernpndpoqRnhueiwbqwe
# Rahsblodluqjr
# YbhftmllhtpmjchxefelouvsgfffcscinrzizfcnrdcmojqiuuRue
#
#
# iter :40000, loss:37.687350
#
# Dtturqrbtjsx
# O
# Tldsaurhtfclhyhmhqrmchviumolv
# Yaotvnc
# Duyuaipyyjenbthcpbbbsuvzo
#
#
# iter :40500, loss:37.449631
#
# Rurecrftdiakotwuqfktoixvtmn
# Y
# Lua
# DautkoantmjvojbewdwezvagrujqmtbeanzlrlavhcwveirnkeNuhuwkoecorhewonutohfmksyqqijjxhyfaxjpogqkhqe
#
#
# iter :41000, loss:37.416327
#
# CaqrfmfxhxrzxyeijzflrgobribntealezedhproclrndzrbszEurxqlezqly
# O
# Obevwxxsgv
# Oilsdiqlpov
#
#
# iter :41500, loss:37.535745
#
# D
# R
# L
# O
# Uhtusftldzyaqcjwhukadorxaswbilhknbrbeaesmgbmmanc
#
#
# iter :42000, loss:37.729095
#
# Rhllnmbxrwrvczribpwsgyfdqaqjqurqjlxjou
# Ohrwrmysmqadwbomclop
# Dsrsvuwvthriyyl
# Cytsfngmrfqrt
# Tpdajrticfhrplfzrlfxaehmfmrwpnddwyekgsnielckj
#
#
# iter :42500, loss:37.643421
#
# RnrnrfrxrsgkntjkfwyzddrablrppprbsmhlnxldwuesqgrutuTshnjbfzaxvl
# Uirgyhpilurgucitsb
# Thefanvmadeheljcskpscisjamaobspt
# R
#
#
# iter :43000, loss:37.679240
#
# Irruqcskzcciabpsxkrhibbcrtazbnxukwpranxunwtbobeia
# Lgaszzkwtnlofzuhmgiyp
# IlhwehobezralpextsjgcgeqoyeftmwcarwehoadzwqbwbnwacOicgrgx
# Easibqlccfzjbmfculr
#
#
# iter :43500, loss:37.626959
#
# Ltplhfmjrtmiguz
# Hlrbbyaxvgoqgjpzvdxzgfmtwsdxgbcgsgww
# Thrtrlqcnmcbiuzz
# OarghyxupsbuveqhycsbxskqcxfiongzaktqgsbvgfwkpogfwuDhrlbfynrkbkg
#
#
# iter :44000, loss:37.415846
#
# Cieoabjodlczjywqvbvsv
# LrrdfqzkbmaqowykeurpajspykqeobeecfgffmqyzzdxtqoeowRhezrkxvaypqsztgsbhavkeorwkqezvivkwzegvbxgatoxgkw
# Ersqy
# Rhrsbnlmsnrhmixmtuyj
#
#
# iter :44500, loss:37.475704
#
# Rtrilujgmzptqjrhznvzb
# Typyfkikkhrfcjtgb
# Yhhsrlvmyulwfqlyqe
# Elnmeshlglpybxfhnjrifivokdojnxeyjge
# Cdsjigvnbdb
#
#
# iter :45000, loss:37.388977
#
# HvrzheturptfyjvdrogwojohhwqymxxkezofepkdehalgiozecTteizhbbr
# Dtrphxwuagodqmokykeuvh
# Rydji
# Yneirprjpycyeurzafg
#
#
# iter :45500, loss:37.160437
#
# Dgytcuumraunqkruourbr
# ApbiylatjszonezqvcttwicveitlcxhikiakrzximuwoolfcxzC
# L
# Dtrgekxyrxxlqyoco
#
#
# iter :46000, loss:37.216251
#
# Rtrlafilrydb
# OprmgnwuwnthgtbtzixlaiabdpnmvmgrjmkvafpjkxtmcxzcjhOtrxjnclehrbjqwzofbxjlzmqswxisqfdpghkafhgbwmqunhajRheugyoxoh
# Rttcapzuwcqbhnesoboykmjzhshmcujgkyhijdkivphphfairo
#
# iter :46500, loss:37.154318
#
# RnegzcoxksasklsniuklunwdzsfbrcorjtytazmrnxozjayitmOhhxquwuuhkhdkpnsmjfpgfevhfgfgpukjevgmkdsocubsttywRaetjwtympowjddgynolrdjpazzbw
# Tythbur
# Rnmlbskjeobtfylvtmatryk
#
#
# iter :47000, loss:37.279682
#
# LpemcgostgevwpdqgwajosqxouotfhgqvipxwdvbopttbgzkanRoruffbfaompoipmtnazkleqoxivputpwyk
# Dprxknonosomieclwbnlghpfonayaznhahtgogi
# Upexjqhjemavgnf
# Uhrngvtgxcjcoeomevc
#
#
# iter :47500, loss:37.299962
#
# Yoryysxfrqmiekxdaq
# Tipetuyl
# Yladoyxhhfwiuiwmngrqugnplmnqafcsrwxwvwojczaek
# D
# R
#
#
# iter :48000, loss:37.293244
#
# RvdlfowlzdkiwboiyyacqmevnopvzfelepvlqffpclxmrargzbEagordobhtouesqqphzgrdzxysacougchm
# LaeoxcklmfrixfkcaystqmwkjrrxrjbywqmhdmwitbbuezmsooTacsxyikjixfelsuopairiutgfnnwztdewrwjkp
# Rithgzgbknz
#
#
# iter :48500, loss:37.322271
#
# Ripicjfx
# Cadlpm
# Rlcuvlqm
# LhrtiylurnjkdooahxumqqmgdoqxhipurutzrmhxochredyewgT
#
#
# iter :49000, loss:37.213277
#
# E
# Hhrnjhadnxdiozmwpnr
# D
# RpatgkofaumdxztzvcsuhqceahosonowvdpcritjpuguakyznlL
#
#
# iter :49500, loss:37.539818
#
# Rpmtvltq
# Otrawpchgxphvfrmvfa
# Uodtsstuvxrpo
# Raauu
# Rarhnlyzvltwvteurahczucdszkhpudn
#
#
# iter :50000, loss:43.791964
#
# RivuroarqszmtjrbxupifjllanfmcsnthcyppakovpaodlwlzzLmrbnvalrkxfauatcjuiugsoychnvhmpcutqw
# Rpecssrirq
# Tpptofeuvkmywbmv
# Hiyyibygwcrwv
#
#
# iter :50500, loss:41.924090
#
# Eipacf
# Y
# Ehruzjrnchxmoirmfwacnbrmxva
# Cgreyfe
# D
#
#
# iter :51000, loss:40.782654
#
# Epcrhkoxpua
# Rgaga
# Rnt
# Dnauygc
# Rhyisyep
#
#
# iter :51500, loss:40.071336
#
# Earzjbpimirgdzrjtkqfscg
# Darhr
# Erpahxbbyxliouokjkrmz
# Ystthvlbfglvpeagcygvekd
# Hireeyewsgfgfcocoxrsfaeipjnijbo
#
#
# iter :52000, loss:39.560912
#
# Tlayhbqnogecrb
# Rtesvmrigbrkhgadquaqjvkujbomrnanlpxezgdgbmeirgee
# Dmi
# DgrekmrvsdwdthzbfcobhztljfdhjgqwjcgbnwauppdsrwrdrgR
#
#
# iter :52500, loss:39.177610
#
# E
# Lpgthpjgptkmwcyoabkravogudy
# Lladhhkzeqwnqbrnpnrzqvw
# Dvylliheiiidwiknkfrmrfowkuuviupuz
# Ipktaszhrorcpbdsghzonfrezmaxtlabxnrhovsnydlurdrchh
#
# iter :53000, loss:38.741794
#
# D
# Dcpsnnh
# Dvrqsday
# Ryeuqzo
# Rhabhnnnwxjmnnwasnzuolrvqr
#
#
# iter :53500, loss:38.454482
#
# LstthhrprgynwoyijijxrfkueoiuryyiwthbrfehexqbufzcouRtrnrnexjcjgs
# YidtfrkzrctjcuqzwhxewvqmgvassafbakqeamrjrqrnextmarEopthcqsnltaaabzaiqdkwfbrnnbr
# Lgrtc
#
#
# iter :54000, loss:38.321501
#
# Dsftcrxgotuiquuh
# Dhgmnezywkwf
# Ripsdpxg
# DarvyvigqxjgrprewpcfrvwealzeaqrwfhxiriflwwmpklwivcRagpct
#
#
# iter :54500, loss:38.115200
#
# Ervzrzolb
# RylnuveqzmrsmuesjscdnvpuhpjdabsqknhsecjirpjlyvxipiYaxtuvptxurkvyjicgfkrlovjba
# Dobylprlxwkmezekkoopdvgmdqruvjjjr
# Evgsamolqbmda
#
#
# iter :55000, loss:37.977667
#
# Rtryt
# Ceaufjqkpyemrqberzpzilgeq
# Opfteycizyjhbm
# Plprrns
# Cphernsiinzrzzjupvqetyziqgakbyhnkvwccufgtngumcqoce
#
# iter :55500, loss:37.772255
#
# EuysaufinzecfxjghfiividlrsyspicxhxtfeueezdfiamtubbRlfprfcurhuwqmdljmapkd
# Eprylpagtps
# Ttbetcw
# Evcgfmows
#
#
# iter :56000, loss:37.516047
#
# Delqpcreetrw
# DpgjvnmuseueoommlkptaupijzkmaucnrnyqsrpbabjilmwtdbRypv
# Duauwctgygcqetssfqewcr
# Ctxuqsrwfaf
#
#
# iter :56500, loss:37.264916
#
# Higmovrwdcgwrzdntjrpoeluahtkuupvebehwaowo
# DwrytkelsoalgmanbdfqtukyouzbcurpoipypmlbqbrkadlixiOnkjmmrdmdxrazgzkdcqrndilurfphiloqoocimir
# Dtbureblvdyiyqrhno
# Eiy
#
#
# iter :57000, loss:37.072928
#
# Epbkpuadbaez
# Eoodgliyhqggc
# Doqddyazlevygkbuh
# Lmgwcqhlr
# Ymbdplhzveehpsaawptiszryznrzolqerxyzpcayhpoo
#
#
# iter :57500, loss:37.058808
#
# Yagajyxajkykcjrnvoasazrmrcjjr
# Etptptpgrheiblrjxipxmbqss
# Yhvizyk
# Eyptoirdbupfpvnezkm
# Yhvzunbnpupngioajnetw
#
#
# iter :58000, loss:37.059972
#
# DgrzqpwckutgwgtfxvjxssnirncvkytqwskiddsdkgkoviksweOpowomqljkkuxxqseuzbzskuk
# Yvruohxapfcnbgzukmvcjmorqnz
# Rlg
# Rlrjeupyptahphgukg
#
#
# iter :58500, loss:37.011685
#
# LgbgyhdzwqrqoirlyitzrxytfgzwzczerswzrggaamgorvrdfuHppsqiroamfpvlrsk
# Rocpcmivwveyrumxt
# Yyudtpnieycipprgkmyitzzhagrxono
# Rgkohewgjhahjuyqrvrmevrubjwifzbnrsrnuyxpr
#
#
# iter :59000, loss:37.060499
#
# Cnrkropwndfxburz
# Ypfdtixzezaucfjqbs
# Lyaymapozirmrjo
# Drszeuburn
# Otavtiegjhvzrumyndvzaugkwobpwxlualrsaawzpse
#
#
# iter :59500, loss:37.024616
#
# Ddgh
# Tipzfjrwxxio
# Plrhatafabdi
#
# Tlrheiggpzgnmkujaqewpbojtncxckgpdrixvar
#
#
# iter :60000, loss:36.955462
#
# Drpifh
# P
# Ryrmmxgxpz
# Ekgssxeixbrwcnrhydnhhavqrq
# Dlbiburxghdgsn
#
#
# iter :60500, loss:36.803824
#
# EmernfbjynqdjvahivaheszmksymaurstiabxuspqvkmwnquchDvrwwoufyrbr
# Yyryzgqarjadwfejliaployvnhbcjuxvam
# Ruxbnjjgdy
# Pkpaslkdilhnjyduo
#
#
# iter :61000, loss:36.792773
#
# Rxrhumevllxsch
# Dgfwmpgigolffltlsdtbutxjobcj
# Dmzdvwflhcgvpvfqgydarntui
# Rxkdn
# Lpkmrzr
#
#
# iter :61500, loss:36.761591
#
# Evvupyhlgk
# EpfgjzgojcjermkigpszafjfrlroounjtsaivcwiautitypmlmDlgmvfey
# Elvpzmpkhpo
# Plcjgzcvqwqztcwuyuadzyynoufhr
#
#
# iter :62000, loss:36.488913
#
# Dybyqyrboiwqaipnciaw
# Rvgawwkxevycojrueeuaqhndbsgw
# Dhrmkf
# Ctgjrybxmcpylnoxwhphvsetad
# Ttvmbmndob
#
#
# iter :62500, loss:36.147990
#
# Eirulk
# Hygjcstnp
# Eyakeyrxfxdlfqzvams
# Etyuasgnogaidqkbfitxedcihssmsowqg
# Blgmxfkusi
#
#
# iter :63000, loss:36.633657
#
# Dvgmzsbhgxfstpgeaiyxrhkaccdwwxvsz
# Dxgmrbo
# Eqsyhjchohrmqvwxzdevflhxfmaisljmfxkqalcuwas
# Rlgjejkwcdjmodpxrpjbfmpupxyvxqs
# Empdvimuzmqvymntniaopn
#
#
# iter :63500, loss:37.016134
#
# Ewjgjxylekzzr
# Clgdyqtvjvkfcaaici
# Hawahglzyvictprhaadpjlwxxqawcmr
# Cvqlddyzenkbkirpnpevakalzrfxknrvqvwz
# Chvvzledrlhfruhbvgfkmtqjauqswxemoowyobaitmqda
#
#
# iter :64000, loss:36.898257
#
# EoxvfzxgfxlkgwjxgvgxzkmbgwxfzfwxxvgwjvgqvmgzjfvfzfEmxvjxxwgvgqwqxfqxxlqxfxjxvgfwfzqffxqvxvwxkizzqvfvCixkwvxzvmkgqxxxkqvjffvgkvkvqxjjxmffvwkzmwbzzgvvjgDlkggpxvvxjvkjxjjxvvxwzkfwzvgggxggxxwzmjbzxfjqvvgxElgxzjvvzkjkzvzxvkqgzgfxkfbgnzxfzmfxxmjxgvvvvgglqf
#
# iter :64500, loss:36.746598
#
# Dvydwrkriakewekaqwoaufbchojxiesiboict
# Ytybspqgvurdjczr
# Eymeeewrqgqvkfuvszzksvunmuho
# Pigxighaubwbu
# Pvndo
#
#
# iter :65000, loss:36.784648
#
# Kyoezpmansapdhswgajezhuuqyjvotvtxdi
# Cgjblrmdygtauojcemmrrmoaejguqonymyqninf
# TmhbhaoqdgigmrvfucuiicmjzrxkudjjcfdzwhlkzvseqeqvmtEmyjbekaso
# Okvcwaomuvxeuaugmvwtmdi
#
#
# iter :65500, loss:36.979858
#
# Ysyviouomybdbmigewy
# Lxlcwu
# Dgxxhlxowwycldurmwuoxdmddcykytlzv
# Eyyeschrldkygxjouavluogwjlxtiruaywukuwlezomlbaqs
# Igyducenqqnrarpyxgjtyaudukdzirxswonduxheuxkdewhpil
#
# iter :66000, loss:37.236311
#
#
# DgdiljiygxdciakcdropnrukdqilvkudytmqchplvoitrjwjmkDjmcu
# Yzhaeqvw
# Rliemexigwtsbailimus
#
#
# iter :66500, loss:37.465263
#
# Eblhveydypudvszacjbrbfh
#
#
# Clqhdpfnryiafewr
# Bdmozgphltivcrwqbedfzoutnalrdloeevdemxt
#
#
# iter :67000, loss:37.379414
#
# Dvibfr
#
# Cwienrw
# Iiieyga
# Bgkgmpkzmpupqrcrldngtkdfhdkjn
#
#
# iter :67500, loss:37.375888
#
# Eglro
# Djicmeybyaielpkpddhgxrgaiyfkhvslf
# Djzdn
# Tmbzeipct
# Dtvecasr
#
#
# iter :68000, loss:37.401009
#
#
# Ljjlis
# Dxqaxrq
# Yytihr
# Eyletr
#
#
# iter :68500, loss:37.787376
#
# Etlyijgum
# Lxsaspzduokccxcosdgrhzmeercom
# Ciyhrbyrdaujbsfqdgnjknygvwjnuoskbwioafzdbfdfn
# RmmhkmftbwmquprcqbsasegxiklqhkmhvwblgldwbpbmxwsjimT
#
#
# iter :69000, loss:37.800942
#
# Dtiox
# Dyvkggyo
# Exzrifpcxyvibfwrqtdo
# ExvristnnrctgvhzuytypsccitbailucuttvqctjfttehxgezxEijesrawimzoxdwa
#
#
# iter :69500, loss:37.796241
#
# Ogxaiaq
# S
#
# Tylfcvcrsmxj
# Fxflkovvjrbpnosiqdjr
#
#
# iter :70000, loss:37.715083
#
# E
# Tjsvarar
# Cturbehuqgdhbuukhxhgdgqwnf
# Clsazdbj
# Nvvbuix
#
#
# iter :70500, loss:37.727395
#
# Ejfguqazinoynjwfgcifmyhlugirhqzjvlmadzvqdq
#
# Bqbphgskbeigecpt
# Dp
# Xlvwaxfnhgarlmwofzujmjubnrtzlgjtmssyuosvvafroxpebq
#
# iter :71000, loss:37.692464
#
# Dmmvbzgaawjdbwfrrahkux
# Dq
# Cjlwvbvtnasxfqnfuwltcgvrvekpmqzzbytzuo
#
# Dqxrjedaeiffulcrxuxwqrehld
#
#
# iter :71500, loss:37.509318
#
# C
# CvibizipgsbcuvnhgzpqvayahqhscaphhctngtvwqjfqlpnpfoFxzcfv
# Tsvrnr
# Izzzwcdpvhxwfitslmwgfymrdagwujnkgxqjvqefuqkwgbyxie
#
# iter :72000, loss:37.205129
#
# Ryjsr
# Oiiynkf
# Ctuoixrctdeyyvdfhe
# Lwlrslqaposfkomhuwbsfegkmry
# Tyvuxygczywokvhgzwd
#
#
# iter :72500, loss:36.950908
#
# Cqmoqizrqflosbqkzomazouygrdgxw
# Sjlowpjvgppawditniuaqbbsbfugkovrevxtdqzajchsj
# Cmniqtylsflesm
# Ofsoaijyqvwobywtyfqiupxhhtmfgvtuorirzeumwt
# Cvwwcapmvtxlw
#
#
# iter :73000, loss:36.742519
#
# Bkxkzznomdsedev
# Lswchacvfhwicelndsyqnmxtiokrqjmqtj
# R
# C
# Ezxpxkxkpg
#
#
# iter :73500, loss:36.573692
#
# Uvxzgzzkclxkiulrfocebqno
# Cvyxnac
# D
# Vzninruqhosdalywcogknowhmtxig
# Vzlgfzlxcncrvovyumewqoiasnhpmsk
#
#
# iter :74000, loss:36.664758
#
# Chmytdiymcmnnhylqvmehcpaw
# H
# C
# Iifgpvjcunab
# C
#
#
# iter :74500, loss:37.043515
#
# Cnz
# Ctjyz
# CkkgmonunteapsxgaulgwtjrmpqvjcogztiohckmmowfivxejiCvbgxbqfsdujdcpfeataqyyvdpfycwdvirfasvlgbjxnqosmzfC
#
#
# iter :75000, loss:37.220893
#
# Yht
# Ijfsbnbtqf
# Fmftipceuanqiyiomuvahrqjhqlyjzezrfpajyua
# Cwvuhqgbfqixhymnpkgzzcuoaqmkeyiztprvdrdblx
# Btzznfstia
#
#
# iter :75500, loss:37.266210
#
# Nwnjmjbtax
# EgsknztieygfooegckffeckxmpsapijnhysqhtiwpmhyhkhzcdEtmjw
# A
# Evdbuaztgxezjqlqiriyxwfgtzcecrthwznlyx
#
#
# iter :76000, loss:37.223617
#
# Usbgiwiptnbzychcufbgxjvwltxcujbyujvjlomwbk
# Cgqao
# Cskvzrxbvvxryvgzvkzknkdjffi
# Czmwnwlfkqul
# Fmfcvsvaertotwpzdcacawtrsicorawejbbehjimuvmnpliawq
#
# iter :76500, loss:37.312801
#
# Rmxchtsoiegfyvzzujckpsthhohhhjxvxomosqlrkke
# Akmddhwobwornctfbzty
# CxivectavxjdtxnwxgkelzawxxbbdvxcwwmguctaeaxtymvevoUimautwspslustowdqwwuagrgbpahrkjsalrsoiaoejojymqaeMtbnifxqgoqqqrdohjeyjeyjivcshr
#
#
# iter :77000, loss:37.316406
#
#
# Tyxomchcurueqyucttnsxrbtieeobxwrjbmum
# Tvfeifdosbvayrt
# Aqnaunsgbdgudzhxanuidfetufth
# Cbbrnbmygy
#
#
# iter :77500, loss:37.126169
#
#
# Bnu
# Hlwxdklodnmxkgppkntxlsjvrpivghzoumkozrf
# Cgzppmmfm
# Ukurwq
#
#
# iter :78000, loss:36.983621
#
# Expidxjmpeeblfnxj
# Lpergyylvduwnqteuvgnnmfoypxrfssegjzantfqwgjtbwvvv
# Chvnpqgfhzzqikgrzvsrmpujkqyrmrhrfwgpjwjogd
# Hmfaykfolbnzuymmuvkmhiio
# Csslhsbquxmhdvboctyctoictwsiuei
#
#
# iter :78500, loss:36.858688
#
# U
# F
# Bsepscuwlr
# Ummaqdddbcatwknrvtoelipwmmuznsxynu
# Bzbamzcaxmdevrbodklrnjx
#
#
# iter :79000, loss:36.694971
#
# Cqksiyboiwqqjf
# IqwrpjsemomckupqykpzvctelalrgamoblcauwebpjdsnkdowaFvxcgthbhctphocovoiwrjxyupgimaxtvctrhriwucctdrszq
# UhmrmhmulksycxuivaihmoxrwpkzmgjeyjzklkdrlrkkvppffyHqwymzuwgjmopubhna
#
#
# iter :79500, loss:36.988126
#
# Evjr
# IxanrxzoiitwsekpigqpufkrzqanpoveyuynsrijwtcqlnemgvCsvfcempynfftfuozpnevtueghgrbllherlzliticasnipuo
# Dnfoga
# Ikmoyczrbbeapnubptjtiamzjuv
#
#
# iter :80000, loss:37.171624
#
# EivbgfdanhqbwsotjrihmojfztkgirdfqfkfhvueiauoarehwaCnmgbjzrqt
# Cuuofoqnuanmgdlfwsd
# Eyzizfvfjfoovchvskxh
# Itsrefzefoyfdfvbwlzrtabsxrmeqbqtbokvvttojdspl
#
#
# iter :80500, loss:37.148361
#
# Efufiekiwlpaqgo
# Cguctoisx
# Cmjaxdotupztitfmcvzjgajftaztmvsiq
# Csqpgnjxuxlqc
# Cmuolaje
#
#
# iter :81000, loss:36.998659
#
# ByzuletyhxqilwixcojyootphmiohbsgkfzpyvzvlxtaczqxkzDgmxopsyladrdpunckzxsxzapykncskgjhoxdifbzautllmfkbCmzqfxdxdfletpihictnyu
# Czbxldduuwke
# Tykfsujatxzmqx
#
#
# iter :81500, loss:36.619748
#
# Hinqxtbbvbjofoocqc
# Txxdmztsgxmhtnih
# EgsilahwnrxohgbexwmctqgcvxvqegmezvcgsfymiivenjtfaaLquiuldoqzyana
# Eivcabtqogcstghrwpnmesygxcirlkhoyyukij
#
#
# iter :82000, loss:36.259789
#
# Ejzpucpwde
# Ccnwuzvypbcfgtlevyeiuvmhlkmuromqvisamylluk
# Emlqyklcidmgmwdf
# Cxxpootx
# Dwswnheopxdwswzemwvcdfuj
#
#
# iter :82500, loss:36.279628
#
# EmqjrooriasgwpbfuvbtkzibtfzcbwbqiyqgmghyjysrpeljchEms
# BgbdldfaaahdtgzpxexwwcwfsyvtztrbjrqbzkbrntecxtxiyeCrsaigxruabewyibdozamkjbarleeenksyldu
# Bwlmzfqrxcph
#
#
# iter :83000, loss:36.657407
#
# Hpkgk
# LhwawbuagfzomyzxuafhgritjonpiylggbcxqxamxkfhxrvyhbHysjxpflftbkltirgvgofajtgauhwtfygpbnaruzcfv
# Hylbh
# Crzwitugncvrsxgllgjezfjh
#
#
# iter :83500, loss:36.786085
#
# Htipa
# Mnudzzwxjxduphjckygoucjxwx
# Fhucloxujwkokys
# Igmaupsrwlprwx
# Ctkattqqsazrhclsu
#
#
# iter :84000, loss:36.908628
#
# Bnkvcoozlv
# Dtirugucjtqrreje
# Hlxe
# Etdt
# Cwwgutukilicowjcnajyxaubihijuxttsjue
#
#
# iter :84500, loss:36.973711
#
# Bgizyqsqbtituruwbtyrprcdmrhzumakdolp
# IzxwbtirmoqgfvpfbgzcxwncjrnwnnjjxjowelvcmrdzjaybukCgmgn
# Lkewmgxiviupbzsatlocgcijlkphtzuk
# Ewdmnrisvyjg
#
#
# iter :85000, loss:37.110570
#
# Ekdkuriouvukisuzuuyrmcbkiwfpmdgogqfkgzvaajvevomt
# Dsftbkeml
# Cwipseeruqgrbjorkgvjfxshfpirs
# Bpstczlrul
# Ohuhtdllmathsywwfrguihijfrmafwgfetvzkkn
#
#
# iter :85500, loss:36.980794
#
# Ejiqlrfbxbghiwnpwcxzyxsd
# Lwlxuegml
# Btxoscmudkzriz
# Blbwvq
# Hydniamcjggn
#
#
# iter :86000, loss:36.817906
#
# Ltwavjvczgwy
# Cnlixgeeqvby
# Cgunvakvmryrirogycsrz
# Enuhpolrzrm
# Bposva
#
#
# iter :86500, loss:36.529962
#
# Fsicuojqt
# Bnojgumsmahq
# Oms
# Oapbjsqomqhwf
# Cwitoknymruntvmbveiqfoaqispw
#
#
# iter :87000, loss:36.335429
#
# Cxszmsmrtihdfrowieje
# Eyoysetxgjiinjvcmflolgkts
# Cguhazwfzrswkheysa
# Bjqqmtqhfrvnknmhmgmagvioihzwlvnyjwlpurfruv
# Cmdnlwuxdmnungthwvtiyy
#
#
# iter :87500, loss:36.890908
#
# Bgulzuzcaenzatzwzipgorwrhgbpq
# Buxcncfydhovwyvjjosalasabckmct
# EtyrlduabohrexypfcpgyfzcgmjdutbryesdrnvridygwfzxaaEtitbflpc
# Cyjqqxxcisfwzrpbienkiflxctrrzpfxzrp
#
#
# iter :88000, loss:37.415137
#
# Yghfypmfyrccvymsynlklj
# UzmnhazqbgjongyslreowbuackafieydtoimbqlriyivjvynygCglomgex
# Evueiapiepbvjbwbqo
# Bssujvgjsayrkvdgnhnlxvlxevgqdmsvxgqplvieeucadwxpde
#
# iter :88500, loss:37.136819
#
# Ewvzhaoctnaimweraeerkevotjsk
# Cqn
# Chzt
# DlszordwsmupccgavhnghtmjyaghsaaltrlrbqvkgljoalvsprBmbzyeacurpysrxrs
#
#
# iter :89000, loss:36.606326
#
# Enxkdlgombfga
# Bsvqmevcpq
# Bjgls
# Smjksrvblasjjo
# Bmsyuqbnioax
#
#
# iter :89500, loss:36.387000
#
# H
# EhixzyteyeenjrdcseyxqcitjocbsalrzobpmpatqzoacsmnwvPxiuhz
# Bkjrdm
# Cvudjp
#
#
# iter :90000, loss:36.207467
#
# Oguwcorletqvpokzbylykjrw
# Dvvsdixodonbtsfjlksbuyyvgtypuonznkxfj
# R
# Ckssznmsnouqa
# Rs
#
#
# iter :90500, loss:36.119642
#
# Cjlouv
# Rvxaswvtenmcuycx
# Rvwvuhidotltkrdgbal
# Rgbjannidbdwan
# Cgjqhoaousnbpojosg
#
#
# iter :91000, loss:35.998869
#
# Nnwtucz
# Cvnsbwxszbmiwourqssa
# Ihlofc
# Rikckpzobtwzbcafyna
# Celmn
#
#
# iter :91500, loss:35.295779
#
# Rlnowrpxaahybpndvbwalakp
# Dkjawomrkcuajrpjlgbf
# Hjua
# Cvua
# Cxmss
#
#
# iter :92000, loss:34.740211
#
# RpzohsfzsplapfnalawniolcyevfolatxiwdsocrsayrsflterDvuzic
# Rgzvdvudlclall
# Rwkjumboxcdiudhrusiouyvrvoucmoqvqcjyvsz
# Bl
#
#
# iter :92500, loss:34.812930
#
# Ehiwatealriftaatsa
# Lsuwpkhodvqwtj
# Bmuawwydyrirxfijl
# Szv
# Lytqils
#
#
# iter :93000, loss:35.254076
#
# Crzsigkrttokndpidx
# RmmruspsxshtybhcsxrnvimrjrgistrpwbimknumifyjdqshkvRmzuatqv
# Rkuewbhrtlryshibfpuhuk
# Dkw
#
#
# iter :93500, loss:35.499926
#
# Rpzreslrhhcelamrtrqenxsekulambs
# Lgstoasrggnjmmtrh
# Ojsakjst
# Rovwoper
# Ecvrhsltcaur
#
#
# iter :94000, loss:35.583361
#
# Sp
# CgnrbxeomzxrvbvofpxrokskskyyotywxhquperhaaxsnrdiltRhrnxjkbuftfnoesdmhhmpeujy
# Fskcpaurcokzscbh
# Rgx
#
#
# iter :94500, loss:35.396818
#
# Egjgngxqsayhlojqnzeeutqfcj
# CvjuelwrtciopodowlxtjqyrkglpfrtpwftswuxhxwdozghabhCksyrhktawz
# Rpkgqskq
# Rsxs
#
#
# iter :95000, loss:35.089566
#
# Cntcekacnpapgthpfapdnzleldutxzgzyc
# Rynt
# Chiy
# Rys
# Rwsax
#
#
# iter :95500, loss:35.029649
#
# EksakbhvdbifeaitnvzdineptbugrouaypjovcwrwfqsgfuezsRui
# Rmusz
# S
# Rwj
#
#
# iter :96000, loss:35.219811
#
# Rpasyieddrfgnliqzzughrucywiwjjemzf
# Hfjyzomezdtrhpmnmycfitphwtandomgu
# Rmgaizerbiwtxjmdiumlapiwucbgmsdfnoyfra
# Cx
# Ohusktvcvmzrbtjczquozqsanetvhbkfezhvukkpuawhs
#
#
# iter :96500, loss:35.254717
#
# Eguohyhsbuuwstlxiagbuesauiaavrqkbgirs
# Rg
# Nm
# Ehsms
# Rtcgelcokm
#
#
# iter :97000, loss:35.142064
#
# Rlawfowrh
# Ey
# Rweosarozmwtmt
# Cgxrtgeexbwrdxmrzoktlowwnrlvudqnowujgg
# Rrwyih
#
#
# iter :97500, loss:35.248055
#
# Rmtpajl
# Gmathhjhqqdonpeqdaorlzvpptivukdwjqiz
# Cjabeoie
# Tuxo
# Cpbp
#
#
# iter :98000, loss:35.434509
#
# Bmescezszbzfuawzmvbvygcxnapr
# Itnkqqirbl
# Ns
# Ls
# Culxs
#
#
# iter :98500, loss:35.640515
#
# Epdottfqlws
# CkukfcicfwpcfqvpmdprlwgyfqvrocrjinzjublgsaggukrpuvDz
# Cj
# Rrwjcyn
#
#
# iter :99000, loss:35.658540
#
# Lhzazzb
# Elnjhqhcqq
# Cr
# Ltcjpfmgardosazgf
# Dl
#
#
# iter :99500, loss:35.521921
#
# EletugawcpxqivldlbnzrquodocdguxjmhudnbbqutqksmzfccEmsajgtexgwxkgvgafqymqarljhdiwecho
# Epvrgvlxaaapuzdouficqcmyjohhpchnu
# Cy
# Lazlwyjedkz
#
#
# iter :100000, loss:35.342242
#
# Umnw
# Lhmulkilxjiwlzpaxz
# Il
# Utwppkidalnrmobavbdmsavzuwapsahzudumxmvowyths
# Cntkaprorjuzd
#
#
# iter :100500, loss:35.172893
#
# Cpfmfvs
# Chkylgzl
# L
# RtwcjbditiwyuemrdtbfqbskzrnmicwkaumgjoebkbickolvovRliiopixs
#
#
# iter :101000, loss:35.052952
#
# Rpncbkbhofzeughdmzqkmqgy
# Cfzrfzicvqng
# Etkhydpqwchbuffkfzslbrcx
# Cnvsjwsblxlfhqvdfsiw
# By
#
#
# iter :101500, loss:34.936721
#
# Rtlqxzdedqatmk
# Htxpdjxpuhirxxamlfuwdfcsdquvbkokugc
# Daxtxynxor
# Yndqnqnwbdafkdxrs
# Bjlsqr
#
#
# iter :102000, loss:34.614725
#
# Doqoudkgsaiduvqfytmfiys
# Fykyiwvmgybskjjgkxeo
# Rylhcltvasluuroynczlnocllohb
# Rsdzsaetdopaqoqaxono
# Ptfunoouiynnwatohdfrtxcrjyitzomjhezn
#
#
# iter :102500, loss:34.109042
#
# Bylyutusbkyt
# Olmzeqbahpxxgsbwchhcdcmvdoledebvs
# Fumwrvfgfydobbqodoqndwui
# Dumrmravusfchqnico
# Rtzyqydolrloxphderny
#
#
# iter :103000, loss:34.081112
#
# Ruqc
# Dxzdirhsyffyuxarorpxixpdpsarizky
# Cg
# Aasabooxlmix
# Etip
#
#
# iter :103500, loss:34.129786
#
# Rhwkjhnw
# Epmjphuavankbrxpugs
# Rt
# Otorphkvunxyykaurfvtgyatwxkjxwliddhw
# L
#
#
# iter :104000, loss:34.289437
#
# Cpbvpj
# Cp
# Nnqfluernijawcddjvbomyzzwrvrxglrjozoarkrhnlluj
# Cyvahdaul
# Dtnrzmofmuihmlnlmfeyufgnqiyrqmisidkizvdobvymjujhbo
#
# iter :104500, loss:34.496316
#
# Ctmkhnwhizjjmrnvvts
# Namjiqlqsa
# Cu
# CznjwtiwpyvkikmhbzviarmguemjmrxsjusauzvpbzcyncmfuyCp
#
#
# iter :105000, loss:34.253752
#
# Ctqunhkrqvzitlgfjakethaacoq
# Eaje
# Ehzcuymiz
# Cnztbpkobgtxztupynjbtis
# Cpzhjbjxie
#
#
# iter :105500, loss:34.036799
#
# Rtm
# Duyuvrhsioulcw
# Eakrvfeoieeg
# Opmubvxkdoft
# Cuufacfzlquzslxdafncsawzbrlovoha
#
#
# iter :106000, loss:33.748394
#
# Ctfgkxfdsaxkmobrnflfwxujbzfpwy
# Cmjhjixeaunqct
# Bgvshhthrvlvuhmnsaud
# H
# Rmnxfmau
#
#
# iter :106500, loss:33.658157
#
# Cyq
# Rn
# Crxu
# IujfxyhojvwizrwogbcesinrmfatpblrlisolvxvxtqrpifrbtRpnuulhqcaqvmvjapyscgn
#
#
# iter :107000, loss:34.767341
#
# E
# RtvxemtknanvpgfwleijaycelpipouurlgleuhurijimupjhlyEquqauhkanhznqxdvgmlmctgcahhbtgiuknobgee
# Rsxv
# Dkqmau
#
#
# iter :107500, loss:35.004374
#
# Raoqfvkvqjafprhrbaadzakndoipzasanemj
# Dazhxctqpvjrffj
# Cangufvkguhhulnnhouoqgluhvt
# Fyjmzbpadolkmytcauuvplftnrtrgdfygjlkgttefcuvip
# Rafvtrsazg
#
#
# iter :108000, loss:34.896310
#
# Yylvgyljxfddidtsfl
# Crwzsfpjabmwvehw
# Rtmkmppqgqs
# R
# Caugpodaauhfyhxxiexsahihhstr
#
#
# iter :108500, loss:34.804804
#
# Enupkx
# Rawtqouvuekhigkzzretvlleccuq
# Rgkyqp
# Raffanhunx
# Rhngitzswffxzoupnbwfzv
#
#
# iter :109000, loss:34.771740
#
# Ryyg
# Da
# Raxydagl
# Ralbhzuqumdeci
# Rn
#
#
# iter :109500, loss:34.605047
#
# Badkdedodeunaxcribhypeuoxxsakvqe
# Rau
# Raqxaflbdouvlfgwwympcowlctyvjxnoxys
# Cporkivpitqrlfzbdoasbycduhzpybifkuyo
# Gawyunfvboap
#
#
# iter :110000, loss:34.443897
#
# Chmzzjauyydohamknrmqhabbprsa
# Aamwtls
# Chxcik
# Rtawcizwicsaiquo
# Rsxkvqs
#
#
# iter :110500, loss:34.218628
#
# RanskwcragorjjfnpribtrepautaqrhasntqwodonuujiitnpbBa
# Ptdqahkibfiduuaausueauaebcdoliaa
# RtmexqilybmmmeppyfapkjpzmofzsahbexkfavcdtoisqpdvntRa
#
#
# iter :111000, loss:33.936220
#
# Rt
# Raernuacqrbrtwdonwh
# Ravqpmaqwnjpkrjxuelidmaqlsfakynuecde
# Frijiz
# Rtmddojcuijlaupbbyhahn
#
#
# iter :111500, loss:34.048285
#
# CamqgjauuvtewedecypyisdovxletazlietovhvpxcxqmjwgbcCaojmqggixzhlgvl
# Aaip
# Rpdkzgdocrqxcslkmlailhfxepsauwapacxctj
# Rphmxzxkupgglkvh
#
#
# iter :112000, loss:34.174639
#
# Opzrpfpxan
# Daaavkautiigwvbhphtcjnzlym
# Rhuswstrjlumufauiljeimnxs
# Rpbparglyshrsaajtxno
# Faomzrufnonnlfitaniqvekbsa
#
#
# iter :112500, loss:34.135908
#
# Chdoloukjjs
# Ntlfur
# Rtxtvruofrbkdoxriouwmzsaqmxvpqh
# Ralweexxarux
# Cabzphveirvryovrrjfc
#
#
# iter :113000, loss:33.885297
#
# Aafrvkfjmbqlapqxyinjvy
# PaovauhnlqyrbzwjtahfarnovmmqyyeuemapsaaxvdxiwyuchdRxcwubvwdboxapsadoilejum
# Rh
# Rawpnxfkux
#
#
# iter :113500, loss:33.427028
#
# Capavrmfczmxsalxhxtxmqujirzvsapobrubrbtws
# Raiklodoztni
# Taxnghchnq
# Rtljaperwjuguxps
# Baoq
#
#
# iter :114000, loss:33.154246
#
# CtafiriqtyqoufdoiifxooxdnpanpngqcxddixgouquratorscHaltuqdomoocceuyouanrovcisip
# Raodgganmjpodopjbobupqmykcugyetxmzlipjleafom
# Rptdxfjgnztgrclgauovcwqzijche
# Rrirmgaaokpjnobrhgcjuzgzue
#
#
# iter :114500, loss:32.823430
#
# Rtukuofnurxqfikecjzhadir
# Ytdepoek
# Rook
# Tt
# Rxlocgpxjvaulqgnuolagfpidoonbe
#
#
# iter :115000, loss:32.391427
#
# Rauuztmifatokr
# Ralrs
# Rolos
# RaosbpmeatatfosaknudapyobhudwcsamksatrhkqnuggbsaugCamrbzugqxlltovrkriuaoqwvojhtbeobxauimap
#
#
# iter :115500, loss:32.190327
#
# CaomucqehkuomrqlggauihlccdumyzauyesawuyjucujfibmvrRtiekpaukouaaghxjubnko
# Raip
# Yajolju
# Caooiqjfcrueauoytvqybwuzwswxbjdobxs
#
#
# iter :116000, loss:32.200196
#
# Ryupviqffkmpqob
# Yaimprgpmuuqatokhiunlrhiuchos
# Yafcanodcn
# Patlloh
# Ratwsaueauodbqhsbqauoolfprybfkannotirrfpuqbnfhnr
#
#
# iter :116500, loss:32.377500
#
# Rauoar
# Raejs
# Raniapoqaps
# Ha
# Daifwourxrnbxbclmrtwec
#
#
# iter :117000, loss:32.552501
#
# Taauoz
#
# Ytrgxg
# Rauomfugivaurjtjvgmgffatknhkptjuucerhlariiompx
# Rnuk
#
#
# iter :117500, loss:32.380367
#
# Racjnwionexejonxlrctuobyuqxiyosgna
# Taign
# Htrufwukbw
# Daowod
# Rtoqhrs
#
#
# iter :118000, loss:32.163269
#
# Tauaqms
# Haue
# Dalde
# Taoyatloipzj
# Ragwufhz
#
#
# iter :118500, loss:32.136692
#
# Rrlwtr
# RaiqgcjppwksgrdouywyvkxrdosaiaurvkuokrbhlgukcduxxqPait
# Raerhys
# Naidijojipfzxyntdos
#
#
# iter :119000, loss:32.289575
#
# Ratrlrtopeujararzsyrfyzctktgqhkewtj
# Dahqgr
# Rayoua
# Caindox
# Tgosfvzybbmaxdpnirmvkouygvw
#
#
# iter :119500, loss:32.804969
#
# Raibwxwsxk
# Thsaurlxzecpuolpjvjrurhqkuigus
# Datwir
# Rlormlbyusyo
# Toiebwuoarkrevqhjswcte
#
#
# iter :120000, loss:32.855192
#
# RhmvzphnudropgdolpktjjwljvmosaxguesatbzpdujmmviswgRalmxqkmwosaxrdonkusanorkrfxjmkvulgz
# Danv
# RairkfgupemtmvwtmeqgurkruoufiphbuhawionckpurygqlpyTahoxzwmgbqcuwaeedatevpghdueakxwkomwjfmxzbnqzmfjql
#
# iter :120500, loss:32.672842
#
# Tarlcpdohyutblx
# RrayjombihulwzxosabpqfunkufrbniousyftuaffqarirzpiqRaoqanirvvifzgmnaawnuntsxcifiobrusztdolsngaclvcoxrCailjmahrolcbokbathosauwrywejpjbjrsaceuophjrvedolwThaopwhxuyqrbbhrlrafjrsahgbikihbiquskonqaueewslaht
#
# iter :121000, loss:32.642163
#
# RalntmtckbogsajtegtiybrfujwnatgrvlatcefonhmxgpgousHaom
# DaomhwmshctvbturhxuoaibqwlatjlnhqrgluiutgonvbkcoukRaulhkjr
# Eaifztjcaliigmaun
#
#
# iter :121500, loss:32.529883
#
# Yanxsalk
# Ttgtxxuepfujvbnonikosas
# Dofobeizdomehpsancgomouevbuos
# Danluilos
# Oaaueonyuzcmtryikolfansahratizylkevtjqxjudyouexhvk
#
# iter :122000, loss:32.008989
#
# D
# Rtmlvmviafhgqbunbrudqglgha
# Rauoxkvwerpcaunigzbq
# Reaaahrcumudkiha
# Ros
#
#
# iter :122500, loss:31.664855
#
# Raooarlnkjggubjrdos
# Dahmenvvjvzewhmryxjavlqriyjeuiuhzokxurxodoftnts
# HannrdrymxvotbgvqaurhfutipdokifowfpxqozhauixuojozjTaapuszyvvzbqker
# Raxtzogobyexudbpwryowiaosamgkcvcvvjqfoauugvozupfwe
#
# iter :123000, loss:31.267640
#
# DardautlcjmqggxpehlyaupiqkxqxogkxwmfjwtghobdyzuimiCanmeckrylydqrxdxzgockyoanantofqxpvyuomozdxqxdemmwRarzglapoksapyaockauuohapqpwfoaoznbqurup
# Raompeajozdotvwzjouixyxz
# Tarugohas
#
#
# iter :123500, loss:31.737566
#
# Basxyr
# Yacfcyilmhhayouxpomffrh
# Daiwkfuoaarf
# Rayeymnoaglc
# Raakacrjhauodoeoaerrvr
#
#
# iter :124000, loss:32.687091
#
# Ranlwouvkoatdope
# Daauue
# Ratruxqrmkkzqouzmrcocvmlzojozcarlmdoelzoirfr
# Yarogheos
# Raurbranrvyyfdgtjrfvupkopowbaynvthwlboqohappbefkln
#
# iter :124500, loss:33.320631
#
# Tazqacodtgpeqlijupgoaloqsa
# Raoa
# Dalnaulj
# Yaod
# Daemnrzgps
#
#
# iter :125000, loss:33.423673
#
# Raafrrunbdlps
# Raifapaoerupmzs
# Raooapugtggrutsvaferkzuyaflyjnh
# Rajdannovgwzfoatky
# Tawrautrjxdortatfgxdjcancgafoguganatmdjrjg
#
#
# iter :125500, loss:33.631705
#
# Rarlcosa
# Patdqoiqerkxqruxgos
# Taquls
# Tareqxbtwdnx
# Dairlrauspfrkrdoodknilmtsa
#
#
# iter :126000, loss:33.497043
#
# Dafvguasrrvhmjurqjmktxaprqvwvrueg
# Dauodaiaztcdaeuiatgyxyqt
# Raroqovlvobrkz
# Ralkmtiuvdxdfxvbuo
# Pasnffu
#
#
# iter :126500, loss:33.165119
#
# Racgis
# Yvtipmmhxjhavjoovrygyoukbpavroaurw
# Naykh
# Rrrrudiglfybfjpsdonrqgpgejcrvlaz
# Raooorvrbwtwanlgunyhbm
#
#
# iter :127000, loss:32.812636
#
# Ranobyuoapsajfkqmt
# Haiobrzgujyivyardosonpzibfjkthkngoiojharroagtp
# Talratblkonrzomkuryr
# Ramcthmobvsaexh
# L
#
#
# iter :127500, loss:32.711315
#
# Uukzafs
# Rargpyxozoalrd
# Rareh
# Hanoxfmy
# Rasaqttvdiwoloh
#
#
# iter :128000, loss:32.389230
#
# Laaseqeesaqearroxjdo
# Caauroxzyder
# Tavratbjprh
# Haaothsl
# Daafbdijrq
#
#
# iter :128500, loss:32.343858
#
# Haataoetbokrmbcrxxqnmwfd
# Yatyhajy
# Has
# Earhbqxvfynxjbapjrhacll
# Hhi
#
#
# iter :129000, loss:32.220028
#
# Th
# Earkatklurvx
# Harecwljnnsairhkmlxodo
# Hrhauwildcurauteno
# Daqjgkpwapnqjzqmvffrau
#
#
# iter :129500, loss:32.299053
#
# Yawotaycwsztwouaauvvanryuaaumefyaufgwyvpwjue
# Yatfs
# Haarlo
# Eaapeo
# Halobqafkdqoyhlodoatzyfwvuutwzpoctfolxzx
#
#
# iter :130000, loss:32.358491
#
# Yarvgqvlxvakuydogwomne
# Rarxbk
# Haauvzauncueetpoqm
# Yathpqaffzlo
# Rrudlgue
#
#
# iter :130500, loss:33.024077
#
# Yaup
# Haaulfururs
# Yaufpctrbwlwarsa
# Ra
# Hanz
#
#
# iter :131000, loss:33.031806
#
# Rtbw
# Dalwqzux
# Tarph
# Huukgdua
# Ra
#
#
# iter :131500, loss:32.624009
#
# Darxurjruxivs
# Yocxzedojorpczuxlxapaujomowlkfhaaczfknuts
# Tarw
# Ranyzmur
# Daaohaecuotppyurkqqoqf
#
#
# iter :132000, loss:32.390565
#
# Raijgqrhauofpqdo
# Ysuhbzantbgwdoidgjbxpjyralqquk
# Rtfjfjrgvjmemkmcgwtxqcaugdnruoh
# Psvrfgcxtjbgkznliz
# Daantq
#
#
# iter :132500, loss:32.827715
#
# Tturh
# Hawmqrauvqauijwjixnl
# Rrfqdebbojzqdoxrleigdomorfg
# Dappgos
# Yafahayfdmcyaejozffph
#
#
# iter :133000, loss:33.443993
#
# Da
# Da
# Ragfdxloaiizamcj
# Yu
# Dado
#
#
# iter :133500, loss:33.824085
#
# Daiqaganebwv
# Dah
# H
# Hu
# Daur
#
#
# iter :134000, loss:34.203115
#
# Da
# Yugx
# Yrbbgwurkk
# Yabkurapargupjanmjisltiwxtdoh
# Danrgwiogqaupqushaepmzbyiyymurltxkgtcxkuxqisifusyq
#
# iter :134500, loss:34.950629
#
# Dadoxojrtrxps
# Tsmgjy
# Haqc
# Isod
# Dazrsaugwluyaukzxhzmhasasaapkkliayqyurpuiluymcqeyf
#
# iter :135000, loss:35.458653
#
# Yr
# Hsmdyfjbqranh
# Hsxwatnsvnbkjqal
# Dos
# Csbvlt
#
#
# iter :135500, loss:36.164839
#
# Dafcerhalnkug
# Donelkbcurghvtcxlpofpkrahauvhaxegenrwojgxhurnws
# Daljh
# Da
# Orurur
#
#
# iter :136000, loss:36.797786
#
# Phvrftmbfs
# Yrkmnqqsksiruoskkdlryaihwosemrctdokksybtdogwkeg
# Doig
# Da
# Iszvseiydajo
#
#
# iter :136500, loss:37.047345
#
# Is
# Rrwdshdaftjvgxmxtlqcnqunjjxmh
# Hsefjrgnwahauekrfnurgsjrtrkfke
# Ysjsmezpcf
# Hlauqegi
#
#
# iter :137000, loss:36.727636
#
# Tafvbznohaljul
# Yslampukqo
# Tabqrohamolopbnzuzuo
# Yskhjgfzuqigmvuxqonolkargdxdufxkje
# Daz
#
#
# iter :137500, loss:36.639559
#
# CsnyfcugnoekbbljprkbuvmeylynxgxiokukiqpqcnrqastfsiDavlxjscdoukkfmgsdgetgbowihanvhazqtgpcwo
# Urviwgtcgq
# H
# Dsxw
#
#
# iter :138000, loss:37.246342
#
# Ramtvebrzzgpsfskhaicxtbdxryoyy
# Dayk
# T
# Gsbzmzisdogyparcuzzqoeylgeeaybb
# Daprnjalnfwqfbfnmtxpnayjmynq
#
#
# iter :138500, loss:37.563030
#
# DamznovwopvwhapodejbifpzgdmqisurirozozgnyeirigirujAsvumkghoklavqyzzvctbdtmnrthutmejwdocp
# Isbvghvrlfbvmqiefrdourgszdqrga
# Rqqomtrsmcglsyjnirclwkxrokwlolhaux
# Dagruu
#
#
# iter :139000, loss:37.783870
#
# DaibjgwakrpejodocmzlkysmqcqtzqkaurgarutotlapxtsjpdEsustdjrzvqiwwjrupqxuqcdtripujkritjrcfj
# Hskwjt
# DobaqvjzjyqpzrwtwbhaqfdeskxqwruajszehahakckvzbwpdoDadotplpwkcrwgisdobglfrvubwpip
#
#
# iter :139500, loss:37.799317
#
# H
# Davcmruugjbojssgy
# Yadoyezygvfmlzujha
# Daunpwvgtl
# Daitp
#
#
# iter :140000, loss:37.627915
#
# H
# Iasl
# Dalpibritkgkxdcmehijuan
# Deuoyhbpvegjbq
# Dapxqyez
#
#
# iter :140500, loss:37.596543
#
# Hsictmc
# Dadotauriged
# Yagebqnqmldoh
# Dkeatamzdahsikmlpjlppz
# H
#
#
# iter :141000, loss:37.438060
#
# Opdactxqhejrznotyymrzyapjmiciglycmwvqcsexduaau
# DaxtgenvlmsfvcnevblxiinfkynprmeokmsnkbsbmnoolmzgxrDaybhanekgftotuksjuixkkfmolascgbi
# Khia
# Crbtluiikhxrqfqefkmsqatntngvuc
#
#
# iter :141500, loss:37.277911
#
# H
# Dabtuziobtfuofentszyyjtl
# Nnnghalayz
# Ulimmbipnmnr
# Dafpqgsmmoungolhazyzlqumgnbgvptrure
#
#
# iter :142000, loss:37.079345
#
# Aqmripukausdgrhadoh
# Hjcavfjzrhezpj
# Davawetr
# D
# Hrmviclouqrkgqapapxjle
#
#
# iter :142500, loss:36.872767
#
# Ca
# Ysibknwzafzxqedohy
# Harkvfgbuooftsvwsyigtklqu
# Anacwzyfuu
# Dahayruydkwntasxymirgfivikirfasntrstbcihprun
#
#
# iter :143000, loss:36.771303
#
# Aajaokks
# Lsdogojgibl
# Yshewopurzl
# Afibxybavyl
# Daheigesupnrumsdxenfwzupkoanqkfubxobchwawjmelaunxp
#
# iter :143500, loss:37.174473
#
# Dawoidqlugkedenhi
# Daha
# Hsbqqmuzzhirulbg
# Osfiuf
# Defobpaakgxwxe
#
#
# iter :144000, loss:37.544501
#
# Raukkvujmmhabgpvmgjmurjqrpxfndwspcivjnpgmclafo
# Hcjhlalmzranidji
# HrufbrerjpluensgatmgurwzonmyrrzchemdmbxgipgzpzcvwgYrztconamdcaegnczgsr
# Devfyxyailjcha
#
#
# iter :144500, loss:37.522886
#
# Hafjeknjgluj
# Dayzixywxkteflnhuddofikwcwg
# Hrunec
# Daen
# Daxwvruxrwoytsh
#
#
# iter :145000, loss:37.319458
#
# Da
# Hsl
# Dapivonbnwsahezvugftsbt
# T
# Yapmdotqyjsndoqxfcyruvnnewfpypgbdohe
#
#
# iter :145500, loss:37.014158
#
# Y
# Daqaudecurndprhablgvtowtnymrjfleko
# Os
# T
#
#
#
# iter :146000, loss:36.776817
#
# HkxjafxrdomksqpwdovclattnkxrdoupujstmovzyofhathwvkDagfalniyxigdoccariqidmyshauukh
# Oghaxasdvggrmtkklavreoymwkyxtjymtjfa
# H
# Yagozmxdebzgsiqsvqgw
#
#
# iter :146500, loss:36.563214
#
# N
# Deiaafqojgueeyyfkhwdnonfwhkomauvif
# Tvubuimwbrwbsvujl
# Dedoo
# Dajxqlicuymixrupkakvgijxelhapjdouag
#
#
# iter :147000, loss:36.371640
#
# Aafltobznmhakrulxrflrkaudof
# Damouidojzlse
# DakbsborvqlbhemhezuotrdofpxruonyngwvyxujbjmjcklkatDalcxehzxqkivf
# Tespdolm
#
#
# iter :147500, loss:36.218543
#
# O
# Ly
# Daqguv
# Ha
# Oeneowuxnsumxvfaiwdozopqbi
#
#
# iter :148000, loss:36.199286
#
# Cavo
# Yafcsytrkjuapononaqhokqjxbbiitbyvbpruqxolldo
# Tevceou
# Oaqz
# Danogyqadbhepkccipcqlnprwrnoh
#
#
# iter :148500, loss:36.502111
#
# Rafpgbuouyhezoiyrvralvbsqheykyee
# Dajqbybo
# Dats
# Ussego
# Aeirti
#
#
# iter :149000, loss:37.266250
#
# Oq
# Csxfucualjufuiaaxuunuauccwujunuvcjtrizuqur
# Avuvvzcsuwuuzcjsur
# Agusbkillrflloluiulvdocmnqlwlp
# Anuzcooadojtheqaxpquujqundcfazllmjubidprukihikguqc
#
# iter :149500, loss:37.943571
#
# A
# Aduquviul
# Dauqluixygmglaytyk
# Aefriy
# Aaunsoiutlgqdovxfesuicwfznmusryrwp
#
#
# iter :150000, loss:37.847884
#
# Aynhtr
# Da
# A
# Agsu
# Ae
#
#
# iter :150500, loss:37.644413
#
# Ojnltr
# Ajen
# Azsz
# DeuyjgkzirpydoxxqmfvwzbpfrxxemhejrdokajuixgvzozkuvOgfrsstyzxrbwlyjkaahbtixfu
#
#
# iter :151000, loss:37.434624
#
# A
# Agupmewmcagogtbapwghyuxdmaqmaluppoer
# Aefoscoe
# Osuolajhircehevkgzibydmcccqoiurqgoeqxylayp
# Avfcpbbapwhesmgzupkpnpmr
#
#
# iter :151500, loss:37.189479
#
# Aspk
# AgrfuyxpqvwhgwzbucjeuwqzdanazhjzclbxohbdgnifhfwqqhLecp
# Agtamptnmcwanxkrumk
# Aeo
#
#
# iter :152000, loss:36.890778
#
# Akuzafuqekgxjoymiouaxomlkbjeh
# Avuf
# Oeh
# AvozprgjtphebkhswrvpgkdosdnqtaxgvqvqozuafssqbjjjfqO
#
#
# iter :152500, loss:36.841146
#
# Agmqaihelrerklh
# Azaujatt
# AzmonllimoiewrafheuxeysstrsxmhyqskwbjdmtehmrkruwhsAgjnivkrxg
# Aepidadoiazclddoinpnks
#
#
# iter :153000, loss:36.989613
#
# Osuxkpvusrpyf
# Ozkjxcdouabgrfdajrto
# Otmrmnvwuuv
# Aqnz
# Azuksxsgoorksjtfdolktaipfesrdoezuka
#
#
# iter :153500, loss:37.150105
#
# Avsgxlipaegwfwaeol
# A
# Awbzisxyptupdoiyekwwmeiccr
# Asfnocjrscgmjae
# Osqrhcryuc
#
#
# iter :154000, loss:37.421877
#
# Aqejxuufur
# Avfolsgdytboplhvjf
# Avgairpyehyjjpplbnpyzobvspukbidoxdlfwluresqi
# Avkyexgh
# Agcoqisaahsrfosahnfyfncvqqdonw
#
#
# iter :154500, loss:37.570746
#
# OsprcrgojaqrqrgpypbofbvhyrxxsozoutryczuvixbhfsiokvOynvsqsffvutfpqvyrcxyyckbgvaubsasbywyhixkaa
# Avialdqjjhnmkyh
# Orftubzxgwoxtaweqvzwvxyvqvjyaetvnsfqgjgvaqwvuajzn
# Afmasjzmzoqv
#
#
# iter :155000, loss:37.570921
#
# Agprcqhsbogpeyhanjjmgcrzujvzazxailsoeerkbducnkqc
# Oehkzd
# Decoizvcsmmsxlsmsjipitgoy
# Aattfobeieheafhajdggygczgqyh
# Aykrbr
#
#
# iter :155500, loss:37.461145
#
# OasiuvfgobcztndelxaakokjqonaxfyekvjuthwrkrdoimrxkiAqksefrtrpjfnow
# Ozkp
# Ovxorpqxkrlbgxev
# Oejbktyfmcbggdjhjczgqfhevpsdq
#
#
# iter :156000, loss:37.244391
#
# Aycrmacxwzvraamkgxnqqeczaxepcc
# Deeglaeiguhsfdzrxe
# Oraadolxfczxbooriqpvy
# Awhe
# Ogwjywffkwjubkinwffdmymyjraynxqrbgjfzczmc
#
#
# iter :156500, loss:37.381518
#
# Atirnlivmavkphscax
# Oreqienjdeogaazpdesoorievubv
# Oeljmpgrfihaurfuupozou
# Y
# Orvnrtna
#
#
# iter :157000, loss:37.677578
#
# Osslfxdousgueancizg
# Armo
# A
# Aspdatwf
# Ozqrpm
#
#
# iter :157500, loss:37.894421
#
# AeipitdombmluvdofeobdonepdgxynilihuypbuegxwchascwtA
# Asnzippby
# Aqa
# Aeeaqabgtfsv
#
#
# iter :158000, loss:38.050674
#
# AstqhgtwdopcizdokdjbnahangcagpirmzheiyonhkjvpphauhOniruaxe
# AvshfajvlmomghlxuseuyalpeanfqpbfdopowknbkrlrmkvbhaOt
# Asutibzvekwfnxqcusbdvp
#
#
# iter :158500, loss:37.911597
#
# A
# ApqavlxavgefdailiiifncsupvmyiaviuojabrsujolnscwhlyAstljgstfxsdnnaunlukzgcbnjbrsc
# Auhsdektngnmbvgtqrbryfyvmdnssidofroyhfmmvaneyp
# Ahwepnmgcjvtjsspubwfrdiaesnoawxgivjgyvmmybmqgnbjhe
#
# iter :159000, loss:37.625694
#
# Aadogjeqemywr
# Atyyvwirdamqnrohukvlbanzxotevdgxrnseshhsipeknwer
# Dezvo
# Attrhaxkxkxs
# Aggacsvjpaxysdpcppvoxhsq
#
#
# iter :159500, loss:37.319257
#
# Orqhqpzhkrprepqmdoljery
# Apffnah
# Oycllxmivcy
# Arlv
# Asu
#
#
# iter :160000, loss:37.134608
#
# Ambwxtsbpgwo
# Agvziamalzvrglvjpwsmqpxquguwzrvdiqituahanielio
# Oyxjdoikxsdo
# An
# Atdoiqwafxichsywnrmzmqdotfbvbylwuriq
#
#
# iter :160500, loss:36.799052
#
# Ahqpkopaconvmnuruaqiafhydobsofzezrrzlsha
# AtyzncjddanoltizyhkpucheqvdoggugifmfftjmjbivecwyjqOywfhfug
# Aeroqmbwughfya
# Abtmwgjttqmqzpiwtoxjlgwglcukuqdalyxcwoqablyoqayfjr
#
# iter :161000, loss:36.634254
#
# Apwdxrepqflzhca
# Asfoutbgmfdopbkf
# A
# Amwpwgikuvdoagtdlovricuv
# Afugugkrieqztoqeyxxrotwckcfckvnkzngdwifekphkgn
#
#
# iter :161500, loss:36.497380
#
# Angnfhpvgq
# Ath
# Atyehunhdonngee
# Afgwysbwiw
# Offddosjrlnjixplnxlwwfkwuyapsiotgzuruolibybdirgwum
#
# iter :162000, loss:36.491087
#
# Ouzljs
# Atjzfrj
# Afvypemzwbumzpirvjatqryxqfpfuc
# Ahopuythzzuxiebpzovuuctojdgkuert
# Aynrzfmapbkomnwowppoyoillltusobilxylwacpeyfcljaytw
#
# iter :162500, loss:36.455137
#
# Atxjbwtlervzipinxirkcgkmbnxkv
# Ageuizc
# Apdoirfnbjmzue
# Ofxcxjh
# A
#
#
# iter :163000, loss:36.375340
#
# AtmpzwcphtuakjlrcexvlddoyajoivkfnlptqqknpticzateyjAtuazocvwxqvsezt
# Atuhernc
# Iskuuezhjbgz
# Athaqrslioxtwujqbnkriqyeyxxduoaudoroqopjzowwicfoaa
#
# iter :163500, loss:37.016876
#
# Aezodowpqoperocwuwwapkqxfdjo
# Atzafd
# Oxejlqfrgx
# Djbotafhfovsidrcviwofzqfsoatfojotopojlyxkbas
# Ap
#
#
# iter :164000, loss:36.284259
#
# ApjohlfyqohxfivourqxriboxoatzmsslcattlvljhcezolcbgAtuoucegiofoktupgoqrbacyrrvxdah
# A
# An
# Amqo
#
#
# iter :164500, loss:36.474291
#
# Amqzrodorputrzkkyyymcvcoumlzzvmoy
# Asaf
# Ayfwejygkxl
# Ahyqgnnsvxlqqdfqphyxkdwperjbdorxpxalhngvajwmtq
# Atqnrtzbwinjpxdoenftelkjegpxzfbg
#
#
# iter :165000, loss:35.856918
#
# Amvrfmanfxrsuyemurugpvdo
# Auqhlllazadohsgihizx
# Oxiiqzrgauemxvaurhfqfmcxqmzofmpnkvcmsdtuhio
# Omouiqji
# Amjmzmf
#
#
# iter :165500, loss:35.225426
#
# Apwmdo
# Amqxjbwxyzwppprbcwqsyoueumnqa
# Agriwtwjauxi
# Akircbllkxjgobtjauuxlgsdsnqhscsuj
# Ajzhascb
#
#
# iter :166000, loss:34.793694
#
# AuqulqkyzzhbrymroofcgbuxqmrgbmmyifcxqswlfxqahswvdoAfevuirnexjhczswfojsfycgqaxyusuotga
# Deaumkckqjqhqmcdxkfhpiufcdudd
# Auyzmma
# Appjdagh
#
#
# iter :166500, loss:34.670991
#
# Ancrovriud
# Avsadofxltpgjyqgpyto
# Avrvauifheyw
# Avntnfnfqwaugavpmcig
# Annhthstrvjgwmscwdkkexdomdprssjdtgjkr
#
#
# iter :167000, loss:35.491749
#
# Axgjvl
# Azmrirsagwmpzzweqodovedonrspdoxkwlipvke
# Ayoqgrtjryuducuouelzstdoxosryogrlo
# At
# Ambcxbywhnlbyazzlquq
#
#
# iter :167500, loss:35.821374
#
# Ommfktusufbvmnbaa
# Ar
# Aidoie
# Afka
# Am
#
#
# iter :168000, loss:36.050834
#
# Amrr
# Ov
# Dzyokk
# Aukkhasnqpbqorlmiowvpdgzkubr
# Asyrxcahuycmyomgdourodbkzpgpuoxq
#
#
# iter :168500, loss:36.259238
#
# Asnzhehroxswiznesxurgridgtvm
# Dpbx
# Ay
# AmbwdoukdothuiufnagrdalzdoazxbpqndlugfuokwbxxptrvxOsvxhugwfynsxxa
#
#
# iter :169000, loss:36.301881
#
# Anfomctrutupzbkezbzxpgmchefg
# Osjofhcb
# Ai
# Asigle
# Angekxjpuxaxdowoyhoezduoemkxjgdounbgbkoau
#
#
# iter :169500, loss:36.235162
#
# Asyihacwbaknbznr
# Ofq
# Axusuqhrtjjqgguxmywosobm
# An
# Anpmuk
#
#
# iter :170000, loss:36.144739
#
# Arikgahe
# Az
# Apik
# Ajfwgsjj
# Azte
#
#
# iter :170500, loss:35.962916
#
# Avlozror
# Azalzx
# Asgato
# Axpxdo
# Avjhufkt
#
#
# iter :171000, loss:36.043575
#
# Azivsrm
# Aruxkjsjitla
# Asdotgcaujfctroauoysfoyworofjcwdssi
# Anyibetjlx
# Asuoxrohcbsclbkfylqjbraxiryvszfkqsboyoxoyo
#
#
# iter :171500, loss:36.272618
#
# Axgobfjfijs
# Arhawbcijyoydo
# Axzqbesrivjrkbgen
# Oytvqqfevaum
# Ae
#
#
# iter :172000, loss:36.276689
#
# Awujeuaqclsjbxhagsmnczxebmcknh
# Aukglalrltejirscjpuirraumzlrrkafixipntitezltn
# Arsyuvnobspkmluihsfavssjzieqsjwzrflo
# Asvwxjrfukihxjb
# Oxucxplrfktyeghelfiqvalsgydafsyjougrlkaruoxdlcuste
#
# iter :172500, loss:36.186775
#
# Asijdokridlsuqjebuzdqymgj
# Doucudja
# Apzklgxwuo
# AsotjibsbdsyfpqpfvsroekhvrlpjrecapwkansusrodxekpjsAyukekkpxtsxssmxrrmqxtklhuyeffbp
#
#
# iter :173000, loss:36.109859
#
# Aglafwbjontjaqurlkukirghko
# Asdooouqbwlqbglzwwioujifktlagdyalsivomptmqfylo
# AsqmvwywhalzitiksenxjtmzfqfdcqgjyzkchubozanqkqpankAsdoovamhuhtoczhvwsvvxvrlcqkyrsvxlrroztksovt
# Ald
#
#
# iter :173500, loss:36.104320
#
# Asoaurqgjodowjsrpe
# Auodnkbpsrnvphdvenpnow
# Aiquuwpfmofodoqnvzmjkerog
# Asimcqwsufbypytcjhwuphsobglfhelahufjxom
# Asllkouewyxkz
#
#
# iter :174000, loss:35.984836
#
# Asorwrszwbqfuqpg
# Asiovajooq
# Aluhjvtlsyiphpsfyludsltzdvocs
# Arocjawfltdojrdocxtavxf
# Asofimnjsyjbhgfpen
#
#
# iter :174500, loss:36.118546
#
# AlxlvxdobniacamzkqshdoiktmvrbmgkeuumnzplxtntvtlzikAsjjne
# Astzepwhdaijtrrbnbdoyhoohhutoqqjzwnlefrqezuwaf
# AsjqnliebqmphtomiotsowzqosmjikpzcgjclqvqbjsqqkbwonArvclrffihmmfj
#
#
# iter :175000, loss:36.185106
#
# Aswmsbyvvviateww
# Artrcrpvjcgbotovevyfubyhbe
# Asdoiclhtvbyzrevlul
# Asuixgeyizscmzzxc
# Asugyhat
#
#
# iter :175500, loss:36.420095
#
# Audozfdaqecqszzc
# Aljncqskwvfqktmh
# Aqygtsjzaufczg
# ...
# Yaaolmszrxrs
# Yaaospluravunsaxtyyup
#
#
# iter :3637000, loss:34.156726
#
# Yaaorkkmqsazrkqgoioxjbquaarkxilvheb
# Yapols
# Yaaolunzc
# Yaaoslotqsawkpe
# Yaaoevesajyervdbrarlugcufsabrllgqvdvf
#
#
# iter :3637500, loss:34.161796
#
# YaaolxfuguxsampgfgvuochunzfuoznugcgurmrxesaejaxrtcYaaoeqpqxzfxbtrwnzmczuyuxs
# Yaportod
# Yapornixxw
# Yaaoljbgblcnos
#
#
# iter :3638000, loss:34.136587
#
# Yaaoevtbounuhulvvqvheubdkuhn
# Yaportoprtveusadlosxrvslxljnkledzsa
# Yaooktrs
# Yaaolqimfatlqvylliugqckxos
# Yaaorhnjiaq
#
#
# iter :3638500, loss:34.181943
#
# Yapolawawuucjpr
# Yaaolcjurgjeedxs
# Yaaouehdycrsatyguillqsafqmkmnvoavujddbtacs
# Yapolxgacioxrgopcaoudue
# Yaaordfgwuevrhpertrs
#
#
# iter :3639000, loss:34.180813
#
# Yapoeutaaqhzhiolqs
# Yaaoleggomxsauxfe
# Yaaosuniauijvlluxbouceozxun
# Yapolzxfyd
# Yatoehpdxzkmmnnbbto
#
#
# iter :3639500, loss:34.241115
#
# Yaaosukmt
# Yaddeykerwrkzah
# Yaponyrcvmgsaizsacb
# Yaaorvqaivjkozzyakwfw
# Yaaorfoho
#
#
# iter :3640000, loss:34.197565
#
# Yaaoltnkzgoou
# Yaaolvuurdxfoplpwztpnnourcwdola
# Yaporyrpcvzsasa
# Yaaolvz
# Yaaollczyuwgauweknnwfzps
#
#
# iter :3640500, loss:34.193266
#
# Yapovhubp
# Yaaorzllijpsaeh
# Yaaorrtwxs
# YapoehgdpngumouloynamwhdoadjtnzbxaiwbjlkieahefnmgyYaponbxirvd
#
#
# iter :3641000, loss:34.144406
#
# Yaooeyfyc
# Yaaorhe
# Yaaovhrpg
# Yaaoelsmpbguzloikbpuwjybk
# Yatoemtxzjy
#
#
# iter :3641500, loss:34.135402
#
# Yaaolsaqrsaaqshgraavkttghs
# Yadolywwhll
# Yaporh
# Yaporkwfjiqirzpnhvteh
# Yaaoilwdoammbjtaos
#
#
# iter :3642000, loss:34.094180
#
# Yaaorhrxwnyoujrzhhd
# Yaaolgpzfarffkyjelowbgps
# Yaporhoibbbahs
# Yapol
# Yaaoeabmo
#
#
# iter :3642500, loss:34.105009
#
# Yapodydbqvkun
# Yaaoryegref
# Yaaol
# Yapolvvpt
# Yapoluwatafxglsjzcnlsnmdv
#
#
# iter :3643000, loss:34.108522
#
# Yaaos
# Yaaolfbmpvrqj
# Yaporhraysa
# Yaaonhlxks
# Yapoemz
#
#
# iter :3643500, loss:34.120050
#
# Yaaolfktreesagvj
# Yapolsajo
# Yaaorhouxkpjfaq
# Yaportmyrbfpjzduhaoubdr
# Yapoeledtmkprsayoqjatdakkjvgtdrlemria
#
#
# iter :3644000, loss:34.100585
#
# Yapoeylmokrjihophs
# Yaeortobg
# Yapogkkufkpeopns
# Yaaoeyoieuvaybouycrlsplgrzrxodl
# Yaeolbdbxtodxubzallirykqwls
#
#
# iter :3644500, loss:34.122688
#
# YaaorpdunurdzadukdzzoarllpvueevuohruhioloymsauduotYaaolphgogrxfhlciyrakatko
# Yaaolga
# Yaporhlmsmxayhcdf
# Yaaolcrlcjxb
#
#
# iter :3645000, loss:34.078518
#
# Yaaoryhvsvzwguis
# Yapoeyjvqsaexs
# Yaaolyxqkzslsazua
# Yaporyhsalplkagio
# Yaaorysxodjlumkdlehpwisuilsgwpzsarwuqmj
#
#
# iter :3645500, loss:34.100038
#
# Yaaoeywqisa
# Yaporyouwgylnmc
# Yaaorycdcmxyijrbxgcgts
# Yapolywmfrylobnzrudqps
# Yaaonyz
#
#
# iter :3646000, loss:34.144984
#
# Yaaoeywiukukduearlwkftljdjrndbkzfmrug
# Yaaolydbtuxutho
# Yadblateubxqlwy
# Yaaoryxaosauoav
# Yaaoryophwavsqxs
#
#
# iter :3646500, loss:34.430837
#
# Yaoovtj
# Yapolyz
# Yapoeyedduqauotsaazdy
# Yaaoiyhiuno
# Yapolyas
#
#
# iter :3647000, loss:34.632349
#
# Yaaorywfwwhs
# Yapotydudvqisme
# Yaaouytulbqjw
# Yaaolytxuacplaklwaqcwleqomwqwoofi
# Yadolycuzpbuk
#
#
# iter :3647500, loss:34.673997
#
# Yaeorydulzlgtkxjvjhbiuofgjyig
# YaeoeydurrpdquiovcvunqtmeepsazvkruhdhxofajwakuhnzcYaeorybgwzrthuymiaxjyisuh
# Yaeolyokrrxennvwmghpvwberaohojrs
# Yaeoeywov
#
#
# iter :3648000, loss:34.734747
#
# Yaeosyi
# Yaeorygyiaecylzqncolzizaiuo
# Yaeolyguisaasnosasasauysa
# Yaeorynawlfckledmbenikgs
# Yaeorytqvnjkcisxpat
#
#
# iter :3648500, loss:34.706416
#
# Yaeorycmkvzsahofns
# Yaeoryjs
# Yaeolydvpsal
# Yaeoeywgygzx
# Yaeolygsagcvruzosfdboto
#
#
# iter :3649000, loss:34.735658
#
# Yaeoryrgts
# Yaeorywfxuoawyksa
# Yaeosyhlukbgeaoj
# Yaeolyopqqfaxayj
# Yaeolyrwlqclonfyxtyve
#
#
# iter :3649500, loss:34.683353
#
# Yaeolyodvwfurkoxkktuyuvkwlewzarvgah
# Yaeolyd
# Yaeoeywptcifwuougzjs
# Yaeolyguqs
# Yaeoeyrufloyo
#
#
# iter :3650000, loss:34.693569
#
# Yaeoly
# Yaeoeyrtrdtloacaedbs
# Yaeosynbktwvyuxuqionngqbolul
# Yaeorytxfat
# Yaeoryo
#
#
# iter :3650500, loss:34.638927
#
# Yaeolywacuelfjdwtrfbq
# Yaeouyvaouwaitcqtanwrlswr
# Yaeolyrcymppvkduouenq
# Yaeovyzgxarnouc
# Yaeolyvuajzzouelrtzouurmexhsadosadhahs
#
#
# iter :3651000, loss:34.797804
#
# Yaeoryfbudl
# YaeoeyizotiloapteflydbhizzdupqlahlurfzvxgisuolsvmbYaeoiygkg
# Yaeosylxxzgjtqos
# Yaeorytndkosaytmlsalborawutmyhmfkmbytqws
#
#
# iter :3651500, loss:62.523982
#
# Yaelytjuyzkec
# Yaeoryruzs
# Ypeorywegnyiomofneps
# Yaeilecelensa
# Ypeoryfecdjxyiwececeyeqers
#
#
# iter :3652000, loss:77.433394
#
# Ypelpvzepukuwuz
# Ypeooydukcpeoabuomcuycdbws
# Ypeiohq
# Ypeiziaaoaytyxalovpik
# Ypeonyhmqfkkzaogjcksauggglouzrwsafkvtuoupaoroaoeql
#
# iter :3652500, loss:83.693667
#
# Ypeotyfqnlmbguovgmkexqhqoaslorbmmlvafbo
# Ypeooyjdb
# Ypeolyoekebhoujab
# Yprlandugabsau
# Ypeolyggduos
#
#
# iter :3653000, loss:85.158210
#
# YpelstxmyunjydcqcypdxuimtpblplmrylouaaosarxxdjyunsYpelonyeydkqrecgcenrololojoaouxosexqbao
# Ypeolymryaozylotwjxlgbbiegdbplowo
# Ypeionoeymtjtqldxuglobd
# Ypemagdbmlxjyrseorygoqcuyaoqvryboutjrqtborh
#
#
# iter :3653500, loss:83.947812
#
# Ypeii
# Ypemotm
# Ypelohomvs
# Ypeosywwbdiutevpy
# Ypeotyogxkcjybzs
#
#
# iter :3654000, loss:81.474830
#
# Ypemonzauasakauh
# Ypeosyiujmqkgpzmzlkew
# Ypeeaqgazgymfsas
# Ypeiha
# Ypeovyjuzto
#
#
# iter :3654500, loss:78.624851
#
# Ypeosytmqbns
# Ypedgnfehuys
# Ypeiitnuvefcfaughaoaxgagzkftmjbaoeyqyzm
# Ypeolynvpasbojfeyrg
# Ypeoqyyixeyloufcyuzupklbfjrrozgfys
#
#
# iter :3655000, loss:75.661133
#
# Ypeieh
# Ypeiohzgwhq
# Ypeotyjljsaxdbdurloukgys
# Ypoleho
# Ypeesnpzya
#
#
# iter :3655500, loss:73.243688
#
# Ypeooyulo
# Ypumoiduokiaxpxufqxcrcch
# Ypeolymhyvtaqeawnsattuzhusaef
# Ypeloeclpzvlowfttdeuynnwhzejqauuhlldrlcbplyjm
# Ypeolybs
#
#
# iter :3656000, loss:71.721698
#
# Ypeopyxxcqkwvvokpmquyufukgkgnawvvsaifixpuzrlps
# Ypeioiks
# Ypeosye
# Ypeiaho
# Yaelehvupmc
#
#
# iter :3656500, loss:70.494924
#
# Ypelatotkjrvus
# Ypeolyouyoucrhkpkbdbfepmo
# Ypeopynh
# Ypeolyivoxpvgiijevz
# Ypeiptjpyios
#
#
# iter :3657000, loss:69.106156
#
# Ypolsprqrjymilyqllozcqlcoke
# Ypelokoqtar
# Ypeopyruklobysaofuojnpnl
# Ypeooyeuxvv
# Ypeosynaolouout
#
#
# iter :3657500, loss:68.057289
#
# Ypeiouk
# Ypeosyrurvwd
# Ypeosyreo
# Yaeosyq
# Ypeepxdujsayyupxtupvqtoefvwsabduyvvdjgzfwfcxhxkpy
#
#
# iter :3658000, loss:66.898205
#
# Ypeionsvqugsaxnuf
# Yaenlhmufufufuo
# Ypeovyvurqrl
# Ypeopyrui
# Yprli
#
#
# iter :3658500, loss:65.781487
#
# Ypcooynzoaoiraffhukdhbrurtiudbos
# Ypellrytoux
# Ypellmyzrioacljftzhvwve
# Ypeiyhf
# Ypedhyejklcljurum
#
#
# iter :3659000, loss:64.691972
#
# Ypeiyio
# Ypeosyfius
# Ypeylauujcgaebn
# Ypenyhrxduy
# Ypeouyj
#
#
# iter :3659500, loss:63.627440
#
# Ypedehcubyclb
# Ypeotyclonozjsaajacdzujmiccujurujbhcdbhgjuo
# Ypeosyuaoueuyakay
# Ypeosynuzsactuknlueuvmzi
# Ypeeotrbyorulgkashubomreomc
#
#
# iter :3660000, loss:62.798354
#
# Ypcooye
# Yppiohyvqzoga
# Ypeooyszsld
# Ypeosyvs
# Ypelysagr
#
#
# iter :3660500, loss:62.355526
#
# Ypiiiipmvqnwr
# Ypeiehyutmeevmnuonluoku
# Ypeietegcjoam
# Ypenafzs
# Ypeestofxeoajlofbsaacwjczavqoutmkfnztbyie
#
#
# iter :3661000, loss:61.994046
#
# Ypeosyjlxukamuj
# Ypeoryruwmfloawxjakuziysamzgppxqzxyuzayagcwayuw
# Ypeolyjuzxymunz
# Ypeoryzioxe
# Ypeiecwaellvki
#
#
# iter :3661500, loss:61.476815
#
# Ypemowyvfaxbrlyldjtqchyzhuibg
# Yaelygdvxxgan
# Ypeosytansa
# Ypemtgpfykcgvyekunfuns
# Ypeoryyjxrmyy
#
#
# iter :3662000, loss:60.977686
#
# Ypelevksas
# Yardarqorbjuz
# Ypeeshj
# Ypcnoheao
# Ypeil
#
#
# iter :3662500, loss:60.351910
#
# Ypeeolyiptis
# Ypelorezdbjko
# Ypeieathmkxbsztzxujkspxprsadelys
# Ypeshmxao
# Ypemonrtozksaechm
#
#
# iter :3663000, loss:59.806990
#
# Ypeovyigktrs
# Ypedeqdbxhgls
# Ypeiaafuwlfbfdcpkbfhyuss
# Ypelos
# Ypedotkazwkpdukv
#
#
# iter :3663500, loss:59.345383
#
# Ypemasa
# Ypeiiaos
# Ypedlayuccfgtiw
# Ypeiomoamgrksfxrnloue
# Ypewohxifilafunknufbfaoqnmdbxnoxtznbrjferaamcaslog
#
# iter :3664000, loss:58.781017
#
# Ypeiilvthkezx
# Ypeiepya
# YpelphyarnriqnhmttrhympwngxdizndyhyutiqiogxnrloqvaYpen
# Ypeyonttynjntbrs
#
#
# iter :3664500, loss:58.249765
#
# YpeeenyamdfrgxrurmicbnynbarmdzgcoayurbqhkmdvwnvhulYpelergrkwk
# Ypcialg
# Ypeoryntolouwjpajasdfjndnmrdnmkngaiigdn
# Ypueahuwgnr
#
#
# iter :3665000, loss:57.823068
#
# Ypeosywahvbeovwhwiouqtthoiujxmrcrnovnkrknlyams
# Ypeiarwxyuibpat
# Yprotyss
# Ypeiesa
# Ypedaismktjfrbszwnoustns
#
#
# iter :3665500, loss:57.701003
#
# Ypelen
# Ypeilamezmiulbguoegcrdnvkmegofqcykcaz
# Ypelolhbqjrpwkkuu
# Ypellugunous
# Ypeloiyeycoleunv
#
#
# iter :3666000, loss:57.286191
#
# YpenigabtgcthfsgtbkiiundeglweevqjuxoukvpdbrfngmlbbYpeols
# Ypenlcjsadnjaajaquzuhajbo
# Ypoesjyuct
# Ypedlmbmsafpos
#
#
# iter :3666500, loss:57.107027
#
# Ypeosyounvetpvqvdujwwiklqs
# Ypeihulehuh
# Ypeiixqur
# Ypehlxrrcnwlkpwxh
# Ypelosahmvh
#
#
# iter :3667000, loss:56.658493
#
# Yppdlft
# Yaeetanixayqrdfivldkriyzetjaygtgornahuv
# Ypelarzararhvpxwrcrbvqxurrpwrinqowtkc
# Ypeehbzunuo
# Ypeylzvaouyqt
#
#
# iter :3667500, loss:56.277801
#
# YpeoehqbniolzvrimdirthymqbisaalezeqlmxolybzxyvgmkuYpeovygopap
# Ypeeotihpvlbphv
# Ypedsaypearhm
# Yprlaedqfqjvjwbbpvts
#
#
# iter :3668000, loss:55.903726
#
# YpeifsarmutnoeocmuejfdxbxxxgwiyaowchocduhaoztibhjqYpeiosadx
# YpeiothvfqxbowxuosauvekwydnjrnothqvbwzrngsafeuekesYpelhhouduiayebigurhqiowh
# Yppiosa
#
#
# iter :3668500, loss:55.640021
#
# Yteolaiuqgwujartyctarijsayk
# Ypeooawfyuhulnrgc
# Ypedctrmrgdbwlx
# Ypeosyqgy
# Ypensrys
#
#
# iter :3669000, loss:55.390434
#
# Ypeolefupmxeekozajxkruprj
# Ypeosyxudzfxours
# Ypeltmqmoue
# Ypeionks
# Ytenaho
#
#
# iter :3669500, loss:55.081346
#
# Ypeestoaytrgksaeepk
# Ypeorapbjxys
# Ypeneurarucajdoasmhaomjvrby
# Ypeorizeuchvl
# Ypeoikk
#
#
# iter :3670000, loss:54.917357
#
# Ypeeduriyuriojgeydkbtao
# Ypeeoteurnpdmknzy
# Ypeleuo
# Ypeovyskorvzyabhyqrtr
# Ypeetqoiolyaywxqchqdobnuvgoiyurwpuo
#
#
# iter :3670500, loss:54.639868
#
# Ypeit
# Ypedimbueuyhzmomfhoaqdhs
# Ypemenzuyuomv
# Ypeorhygqninfwbundjfo
# Yplovyjalblacbu
#
#
# iter :3671000, loss:54.502693
#
# Ypelawgyo
# Ypedosaqrugzcunjepyvcxcqyko
# Yaenos
# Ypelizyhiwdvhff
# Ypeeehxfpaotikxs
#
#
# iter :3671500, loss:54.326161
#
# Ypedeanvipjiwmrpjvruoxzpps
# Ypeheujg
# Ypelivyuolmxkurakqtetxqbqvjaturors
# Ypelipojp
# Ypelraxhjmymz
#
#
# iter :3672000, loss:54.089994
#
# Ypelsgoggqobraczkzqvtuxdobolygkdx
# Ypelnuhmxjrlbqvtzrgmowxqhjrwtalfvsaqxlgmt
# Ypedotnaopycvaxholxmumxboyrtokxqvbrrhuycseoqoxw
# Ypehbu
# Ypenanywrmnkcutaeujuuwybvqolo
#
#
# iter :3672500, loss:53.945690
#
# Apeosyn
# Ypeeuuyiyiwbzev
# Ypencnwxjad
# Yaelearsas
# Ypelahvxnnzxkcys
#
#
# iter :3673000, loss:53.880703
#
# Ypeietd
# Ypelauinlsaorcobn
# Ypeol
# Ypeoriavkkjgsumgdubij
# Ypeyadzbrtkfys
#
#
# iter :3673500, loss:53.839734
#
# Ypeiotettarorya
# Ypeoruv
# Ypeorrhsagytrxtax
# Yppir
# Ypeieaugqdopy
#
#
# iter :3674000, loss:57.867744
#
# Ypbyivxyogdbrdqggbyhkbkuygqmuupfigiezggijvzrdux
# Yprloth
# Yphlahjgwbruzbkzrxyvqpdcjtjs
# Ypreonkuqnctksafreq
# Ypneiuo
#
#
# iter :3674500, loss:56.380865
#
# Yphiaucrkpoggyxxqzcuz
# Ypholmckyewjfjoms
# Yprovyisazcuflylogvjwmcrjjtemjoeigxbyde
# Yprosyu
# Yari
#
#
# iter :3675000, loss:55.405213
#
# Yprlotgwgamzfndbuattgucbyyynr
# AaposymifagffacrrufarmtiosakrawmozrbrqgtylybyrgngsYadbosaiopgidbrfpbgjgivpntiayvyabjgjtugwyz
# Ypeosyxruqdurrn
# Yahietikfkylmaopfuouzjvuruxapntegaot
#
#
# iter :3675500, loss:54.657073
#
# Yarieteopbyhkokmqryv
# Apdclcns
# Yprih
# Ypcdanevusautrdbxqfrtfxaebp
# Aprlexjvrarvrrnbrarawckhcxo
#
#
# iter :3676000, loss:54.075452
#
# Yphnvhoph
# YprdosacmttynorkrzmdftxahcxavuketnkrtuokncmxngogrrYacleughontrvu
# Yaddaui
# Yaesiyrickouftx
#
#
# iter :3676500, loss:53.616042
#
# Ypgisey
# Yphloorkgqcwguzxfxtydbtaqzoafs
# Ypdbsi
# Yprdooxbyjiavxgbipoqjcraredbfigmyrwajarvhphawbf
# Yptousa
#
#
# iter :3677000, loss:53.451740
#
# Yphlolrekh
# Yarotnnrxwchfsabksabo
# Aphosyotwac
# Apciernataiatbyxocvpaxrkrljs
# Aprorgesazjiyaogmlgaoloefttuwuhgqhy
#
#
# iter :3677500, loss:52.918908
#
# Apdkpdwvkasehjrhguovlmnipmgtxtyar
# YpdwszyunqvaxqejgwvhvvxafhozrxxnrzlemibnzdopkhcnetAphitijpjeflpgrlogfufhovoqiqgho
# Yphig
# Yardcnfhgkpci
#
#
# iter :3678000, loss:52.742154
#
# Ypheolquqanmtuo
# Apeosychrfk
# Apdbeujafaxnrhjgelotkukrj
# Aprnlxqdnhp
# Yppipttrrrwaovqepua
#
#
# iter :3678500, loss:52.570761
#
# Aprleassaephyuvneao
# Aallos
# Aphovyr
# Ypuovyfaizn
# Aprlonwzxholfqm
#
#
# iter :3679000, loss:52.524751
#
# Aprdosavhzn
# Yahitvdupboivprec
# Apwosycuxaogcdd
# Yporoneim
# Ypcseuqcfhidbuegrcoiquyuoxlctjxpfnwdaijlcfjhjvruqx
#
# iter :3679500, loss:52.313282
#
# Ypreoloufuranrdqokodrnnuoxsxdub
# Yaholgthfbyunzrsaev
# Aarorcf
# Yphosyefnae
# Aaherdxuylokwhpgo
#
#
# iter :3680000, loss:52.248145
#
# Apdblnstraftyhbzrrwhzucnzio
# Aayilafiiwnnlikpts
# Aarorlmddbjmeiorhbrjyunsayuahmxmh
# Aahllizpfcrkgbotwfvuokejzromoqnrcwnwoprs
# Aphiihc
#
#
# iter :3680500, loss:52.078837
#
# Aponosautbnlqghlommcm
# Apeisuhmyiktwhwnsajdo
# Aahie
# Aajosylbpvn
# Aaecolkvxbztzmjjrrrlnsauemzfymyvylwxyayio
#
#
# iter :3681000, loss:52.036370
#
# AppmawbnbajzrfrordlbeuiklrxliftuxxfloutahmdutctzgjAarieuybpytqomkjojbrejpunwsududuxnroraofhmy
# Aphonjeurlwzsij
# Aahosyo
# Apdbonttrtnuoeolbfbgactuhxgagrduhdhqgeoev
#
#
# iter :3681500, loss:51.881724
#
# Aahieylvwuo
# Apgiosavqtxarrtiqyeph
# Apylsixhmfzrysabkypxkakigs
# Aarits
# Aphaaxw
#
#
# iter :3682000, loss:51.817697
#
# Aprosybunhyqss
# AphosybvbfvmztrzogcwtptxruohwqivrgovkhobdujxiuokjuYahlaurfc
# Aprdonywjzduhxduy
# Aardosanovsupmhkd
#
#
# iter :3682500, loss:51.754426
#
# Aphosyyfps
# Aphiswdusunnyeejwsaarnrpqdbakmqbrtwhrao
# Aardzaivwaountvaiexihuypxufrourlxafnfosuhtnmjchs
# Aadcl
# Aprhea
#
#
# iter :3683000, loss:67.846876
#
# Aprdejyrrayaonokofombayzpadbyrefbaeuh
# Aarleavaefgaeavayunarayarvxarahjyayorwgqr
# Aprleabuyarkhad
# Aardosaayavusidbekgs
# Yprllmducayiys
#
#
# iter :3683500, loss:91.415266
#
# Yprortkiwdczcsabzpypktkajtnprpyajcncypqa
# Yprortrhntwpnxnuqiyjyiz
# Yprisukanahpapyayprxguksabbprvh
# Yprolpkuzpkpvavtbvhps
# Yprolbqijsamqpypkdktziq
#
#
# iter :3684000, loss:83.174841
#
# Yprovhz
# Yprovhjlcuyifosepiquyuo
# Yprdyrelcjymnuznn
# Ypritmjifsahyxqatigpgkndrzhpiinbnphphpkiy
# Yprovhqjuwnbquqrxrhdjlkbzthbfbvnhpzleayly
#
#
# iter :3684500, loss:74.091920
#
# Yphies
# Ypeonzllhwnibcrrtchbhfekokoloakwh
# YphosyowvubiybcrrankyqawmuhtfrnaqadubulqyonkrqymsbYphoriqdhsatyufph
# Yphosycuvsa
#
#
# iter :3685000, loss:67.275591
#
# Yphosygsagobo
# Yphoi
# Yphirvduywrayayviotafptwzbhijayee
# Yphiolzxxxrrqhkbtbtrjuduquimsbzikpvfycuanryi
# Yphosyvaufqsaxvttsasamqjpvzvzevxzsabmfx
#
#
# iter :3685500, loss:62.660671
#
# YpholzthlvrasanmhobagqoafekiwvtcriramwtigprrpespuqYphovhl
# Yphovyxroqs
# YphiosaqfigmnqrrebhdawmtsgrpezeucqcuaaslpysvzaducaYphilwrndbrwhzuudbhwraipdbwreudqtqrwrptaxcgrhbxexk
#
# iter :3686000, loss:59.526655
#
# Yphol
# Yphorhkcoazmjubujlybkuwiytjrkgqfezduk
# Yphiosaouukknmokcwjxttpvjah
# YphilhzapgcrpbqhlpjvqricnaqarsatrbgxkrjuzsaouaqfthYphochzs
#
#
# iter :3686500, loss:57.311589
#
# Yphovhfablymranuowns
# Yphosybartiuhqdjwunsal
# Yphorthuk
# YphoimsleagfrhygvcoayjnatigzdbtkdurfhacmeikjdbpqynYphosynibukqfujjes
#
#
# iter :3687000, loss:55.854472
#
# Aphosynhqaygfrratou
# Yphosyrtthpvvnyxbufznsamtlvbzri
# Yphopyszngfccgqawkruhym
# Yphosypuh
# Yphooiqpzmflyudbts
#
#
# iter :3687500, loss:54.836462
#
# Yphotctmicog
# Yphoenevrnkyrijwosavts
# Yphotuevracfrix
# Yphosycabnyrpgovsglursa
# Yphochjbzaqvktwemurayros
#
#
# iter :3688000, loss:54.050640
#
# Yphoemovyacuycragbkaitkteqbs
# Yphoutyip
# Yphovhypobxxiwimqs
# Yphorrckhhknxs
# Yphoouxunarjvtjoruzim
#
#
# iter :3688500, loss:53.432669
#
# Yphoelgs
# Ypeosyswh
# Yphophzuo
# Yphosyyggmoldb
# Yphosyjxruqqauzerlziyvraclzdpimsal
#
#
# iter :3689000, loss:52.902317
#
# Yphopytiz
# Yphoorrayywrrmo
# Yphoubihyuhbjs
# Yphoeleouqvasi
# Yphovysbtukrkakuhytayaopquavnahurvqmg
#
#
# iter :3689500, loss:52.499331
#
# Yphorlktduhaeu
# Aphosygaoxxfts
# Ypholwdbgzljxosqxaelzzylyivvh
# Yphosyncruraurmmbs
# Yphosyjugaojxrojs
#
#
# iter :3690000, loss:52.150388
#
# Yphoovrijcrbbnoal
# Yphosyylzdrarizus
# Yphoovjukhxucvrs
# Yphoshyksjeqpucurua
# Yphollqa
#
#
# iter :3690500, loss:52.029293
#
# Yphosywxu
# Yphochymrxturups
# Yphosyhlenyhmbbhzghfl
# Yphosyinrjvke
# Yphopyyyqrqrxhwfosawratawly
#
#
# iter :3691000, loss:51.936498
#
# Yphovhlsaqnatpelhjyararuwaraezfarcnsazyrm
# Yphotkrroubsasaqoqm
# YphookydqiyqruiwztytrrdbduuayadbyuctznffgajjypozttYphoesaegueuyfo
# Yphosyxufsakrtrvrsa
#
#
# iter :3691500, loss:51.962686
#
# Yphorazuys
# YphorfgpixjurhwjogscovcuiiwlgdqaoajilupocppecgemroYphororckut
# Yphosyzxxxwvruosaqnffiyvjawh
# Yphoefpakrocmlyymvbfogcxhbizivyaquogrsalkpysauavqa
#
# iter :3692000, loss:51.842653
#
# Yphola
# Yphoojqrtaxicivkohos
# Yphosyvzeuh
# Ypeovybikwoqcrpursalozowyw
# Ypholbomhuwtojrabfzurjhcglbngerpycravwvkeutgjjxurq
#
# iter :3692500, loss:51.260947
#
# Yphosylokpquh
# Yphoricvavj
# Aphosyhaduqhbubqomztrtgptzedwtzekij
# Yphoweytopfujcoakgmmjuqvwxgwmhw
# Yphoorwnyhduwujcotgazafnfawadbvhwfziwtzhkizaqixbob
#
# iter :3693000, loss:50.485827
#
# Ypholqrsahyzmibznnhuyai
# Yphoutpievnifehcbzravucuyzo
# Yphoimvmxtkrfuvayawmyhpuoxrxrjnpfvk
# Yphorufabta
# Yphoeazntkeuos
#
#
# iter :3693500, loss:50.017261
#
# Yphovyxddbdbs
# Yphosypakrimiuo
# Yphovhtbvrprluhjfshlbithlmnlmqknfigdrdoffov
# Yphocyfatbojrrdkxhpwjqrrxbekrsaghqphyqh
# Yphovhxtskwqomvlqjolokrkxrokihqajwskxugupjxwtpbsac
#
# iter :3694000, loss:49.608208
#
# Yphon
# Yphovydvruqxopjixiq
# Aphosywaoyyrwajsaznzjxehqbzs
# Yphooarimnfmwfilwdsutxzu
# Yphoshmufsafrs
#
#
# iter :3694500, loss:49.436591
#
# Yphotycflxr
# Yphorae
# Yphotpduomztrupawigqhkgsa
# Yphovynwvucarxirradqrzkrfhiuyaiknjgafs
# Yphovhvanor
#
#
# iter :3695000, loss:49.241140
#
# Yphosywhvhiqnhnutaekovyrtnptouludbg
# Yphosyeldbshv
# Yphoi
# Yphououxnjlcaayaoxncglburhw
# Ypholugwo
#
#
# iter :3695500, loss:49.080555
#
# Yphooxjxrlyad
# Yphooxsgnxe
# Yphontjduuxvwukkfvmiwurhjazbrmlaymtiedh
# Aphoshzfogtdvuqcxdspd
# Yphoehogjakvhakmitnrkuzrcldusaqxqvvetzhs
